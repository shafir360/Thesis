# %%
# !pip install pandas
import tweepy
import pandas as pd
import numpy as np
import requests
import os
import re
import csv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/fyp/fyp2/tweets_bitcoin_235024.csv')
df = df[~df.tweet.str.contains("#BTC",na = False)]
df = df[~df.tweet.str.contains('#Bitcoin',na = False)]
df = df.dropna()
display(df.sample(frac =1).head())
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (0,2,3,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Unnamed: 0            id                       time language  \
# 201426     201416  1.535143e+18  2022-06-10 06:11:17+00:00       en
# 116641     116639  1.535250e+18  2022-06-10 13:18:06+00:00      und
# 80885       80883  1.535283e+18  2022-06-10 15:30:36+00:00       en
# 91730       91728  1.535274e+18  2022-06-10 14:53:32+00:00       tr
# 80679       80677  1.535283e+18  2022-06-10 15:31:13+00:00       en
#
#            author_id                               geo               source  \
# 201426  1.394846e+18  {'place_id': '3df4f427b5a60fea'}  Twitter for Android
# 116641  2.543893e+08  {'place_id': '000f50400f2ec9b3'}  Twitter for Android
# 80885   1.272797e+09  {'place_id': '34c5228937a15b4a'}  Twitter for Android
# ...

# %%
display(df.sample(frac =1).head())
# Out:
#        Unnamed: 0            id                       time language  \
# 167737     167727  1.535190e+18  2022-06-10 09:19:33+00:00       en
# 18414       18414  1.535347e+18  2022-06-10 19:43:29+00:00       en
# 80092       80090  1.535284e+18  2022-06-10 15:33:15+00:00       en
# 177457     177447  1.535177e+18  2022-06-10 08:26:37+00:00       en
# 101489     101487  1.535264e+18  2022-06-10 14:14:53+00:00       en
#
#            author_id                               geo               source  \
# 167737  1.533900e+18  {'place_id': '00e55e2b4c491c5f'}  Twitter for Android
# 18414   1.485306e+18  {'place_id': '512a8a4a4c4b4be0'}   Twitter for iPhone
# 80092   1.464729e+18  {'place_id': '3b77caf94bfc81fe'}   Twitter for iPhone
# 177457  2.432998e+09  {'place_id': '00ed45c91ce44a48'}  Twitter for Android
# 101489  5.528594e+07  {'place_id': 'a592bd6ceb1319f7'}   Twitter for iPhone
#
#                                                     tweet
# ...

# %%
df_1 = pd.read_csv("/content/drive/MyDrive/fyp/fyp2/head.csv")
display(df_1)
# Out:
#     index  Unnamed: 0            id                       time language  \
# 0  167737      167727  1.535190e+18  2022-06-10 09:19:33+00:00       en
# 1   18414       18414  1.535347e+18  2022-06-10 19:43:29+00:00       en
# 2   80092       80090  1.535284e+18  2022-06-10 15:33:15+00:00       en
# 3  177457      177447  1.535177e+18  2022-06-10 08:26:37+00:00       en
# 4  101489      101487  1.535264e+18  2022-06-10 14:14:53+00:00       en
#
#       author_id                               geo               source  \
# 0  1.533900e+18  {'place_id': '00e55e2b4c491c5f'}  Twitter for Android
# 1  1.485306e+18  {'place_id': '512a8a4a4c4b4be0'}   Twitter for iPhone
# 2  1.464729e+18  {'place_id': '3b77caf94bfc81fe'}   Twitter for iPhone
# 3  2.432998e+09  {'place_id': '00ed45c91ce44a48'}  Twitter for Android
# 4  5.528594e+07  {'place_id': 'a592bd6ceb1319f7'}   Twitter for iPhone
#
#                                                tweet
# ...

# %%
df_1 = df_1.drop([ 'Unnamed: 0','id', 'author_id','geo','source'], axis=1)
display(df_1)
# Out:
#     index                       time language  \
# 0  167737  2022-06-10 09:19:33+00:00       en
# 1   18414  2022-06-10 19:43:29+00:00       en
# 2   80092  2022-06-10 15:33:15+00:00       en
# 3  177457  2022-06-10 08:26:37+00:00       en
# 4  101489  2022-06-10 14:14:53+00:00       en
#
#                                                tweet
# 0  @BTC_Archive @Salon ✅ World First USE -2- EARN...
# 1  @kusamakaze @NaithanJones @jack @ItsKennyatta ...
# 2                     Here is your sign, buy bitcoin
# 3  #btc is still holding at $29k to $31k, but soo...
# 4  @God00836385 @rovercrc So don’t buy it and mov...

# %%
df_2 = pd.read_csv("/content/drive/MyDrive/fyp/fyp2/Bitcoin_tweets.csv")
display(df_2)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,5,6,7,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                         user_name  \
# 0                                   DeSota Wilson
# 1                                        CryptoND
# 2                                       Tdlmatias
# 3                            Crypto is the future
# 4        Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader
# ...                                           ...
# 3543848                          🔔system'cRe5520'
# 3543849                     Bitcoin Price Tracker
# 3543850                                 Astro Bot
# 3543851                            Job Preference
# 3543852            Bitcoin Price and News Updates
#
#                          user_location  \
# 0                          Atlanta, GA
# 1                                  NaN
# ...
