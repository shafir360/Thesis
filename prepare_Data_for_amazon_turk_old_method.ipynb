# %%
# !pip install datasets
import pandas as pd
import numpy as np
import requests
import os
import re
import csv
import glob
import sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = "/content/drive/MyDrive/fyp/fyp2/sliced cleaned data"
output = "/content/drive/MyDrive/fyp/fyp2/sliced data for turks"
all_folders = glob.glob( (path + "/*") , recursive = True)
print(all_folders)
# Out:
# ['/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata20.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata21.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata22.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata23.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata24.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata25.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata26.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata27.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata28.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata29.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata2.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata1.csv', '/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata3.csv', '/content/drive/MyDrive/f
# ...

# %%
for file in all_folders:
  df = pd.read_csv(file)
  df['text'] = df['tweet']
  new = df[['text']]
  print(os.path.basename(file))
  new = new.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
  display(new)
  new.to_csv(output + '/' + os.path.basename(file),index = False)
# Out:
# labellingdata20.csv
#                                                  text
# 0          doge dogecoin $doge           __   BITCOIN
# 1   TODAY is a perfect example of how destructive ...
# 2   &gt;!! bitcoin  Alert !!&lt; \n1.67K btc (65.5...
# 3   Collaborations with different tokens are going...
# 4                          Could get scary\n\nBitcoin
# ..                                                ...
# 95                            _lores Big yes Bitcoin
# 96  Biggest Updates on Satoshi Public Chain Loadin...
# 97  The $BTC price is at $40,693.61 right now.\n C...
# 98  I am happy to join your project. Based on bloc...
# 99  Bitcoin giving you a Black Friday discount! I ...
#
# [100 rows x 1 columns]
# labellingdata21.csv
#                                                  text
# 0   Strong  and futuristic project guys join ASAP\...
# 1   Liquidations in past 24Hrs  bitcoin btc Crypto...
# 2   Announcement\nWe are pleased to announc our pa...
# ...

# %%
display(pd.read_csv("/content/drive/MyDrive/fyp/fyp2/sliced data for turks/labellingdata17.csv"))
# Out:
#                                                  text
# 0   _binance The only projects I've seen doing mor...
# 1    \nSome x 10000  is possible after CoinMarketC...
# 2                              0.0013 BTC (78.99 USD)
# 3   Many people make the mistake that when somethi...
# 4                        Nice scenario Mr Bitcoin 😁✌️
# ..                                                ...
# 95  BTC Update! Following the previous tweets, we ...
# 96          $39,510 \nBitcoin BTC BitcoinPrice Crypto
# 97                             \n\n$vgx btc eth $usdc
# 98   This Week’s Crypto Recap  Bitcoin Cryptocurre...
# 99   Ethereum Reverse Losses, What Could Spark Ral...
#
# [100 rows x 1 columns]

# %%
df = pd.read_csv("/content/drive/MyDrive/fyp/fyp2/sliced cleaned data/labellingdata4.csv")
display(df)
# Out:
#     Unnamed: 0  Unnamed: 0.1                 date  \
# 0       267546        268227  2021-07-05 12:44:59
# 1       854087        857277  2021-08-21 06:36:31
# 2      1697697       1704092  2021-11-12 17:00:07
# 3       935685        939331  2021-08-18 02:35:55
# 4      1683183       1689563  2021-11-06 00:52:40
# ..         ...           ...                  ...
# 95     1866732       1873332  2021-11-26 08:26:06
# 96     3436100       3446144  2022-06-03 19:00:05
# 97     3386943       3396774  2022-05-28 23:53:30
# 98     2032215       2039072  2022-01-13 17:44:07
# 99     2526222       2533775  2022-03-16 11:56:09
#
#                                                 tweet  is_retweet  real_score
# 0   What if $BTC goes sideways ($30k-36k) for the ...       False         NaN
# 1   I will not be leaving their platform ever! I w...       False         NaN
# 2   $CAKE $SOL $BNB $LUNA $HOGE $DOGE SAFEBTC $SXP...       False         NaN
# ...

# %%
df['text'] = df['tweet']
new = df[['text']]
display(new)
# Out:
#                                                  text
# 0   What if $BTC goes sideways ($30k-36k) for the ...
# 1   I will not be leaving their platform ever! I w...
# 2   $CAKE $SOL $BNB $LUNA $HOGE $DOGE SAFEBTC $SXP...
# 3   Astroctopusfarm is a good project and have a s...
# 4   Crosswise presale hits softcap after 14 minute...
# ..                                                ...
# 95  These blackfriday deals in crypto are too good...
# 96              46.29% Bitcoin Altcoin Cryptocurrency
# 97  _C The decision is good I think \nLet's go get...
# 98  People still don't use energyblast indicator t...
# 99  _Maestro ViralCrypto a Defi platform for freel...
#
# [100 rows x 1 columns]
