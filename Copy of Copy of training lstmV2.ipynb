# %%
# !pip install tweepy
# !pip install configparser
# !pip install pandas
# !pip install transformers
# !pip install datasets
# !pip install tqdm
import pandas as pd
import numpy as np
import requests
import os
import re
import csv
import pytz
import sklearn
from datetime import datetime, timedelta
import pandas as pd
from transformers import AutoTokenizer
from transformers import TFAutoModelForSequenceClassification
import tensorflow as tf
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import glob
import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score
from sklearn.metrics import matthews_corrcoef


import pyarrow as pa
import pyarrow.dataset as ds
import pandas as pd
from datasets import Dataset

import re
import csv
from transformers import pipeline
import torch.nn.functional as F
from transformers import AutoTokenizer , AutoModelForSequenceClassification
import torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: configparser in /usr/local/lib/python3.7/dist-packages (5.3.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.21.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.9.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.4.0)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.8.1)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.9.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.0)

# %%
import warnings


import pandas
from tqdm import tqdm

def labeller(directory,dataset):
    warnings.simplefilter(action='ignore', category=FutureWarning)
    tokenizer = AutoTokenizer.from_pretrained(directory)
    model = AutoModelForSequenceClassification.from_pretrained(directory)
    classifier = pipeline("sentiment-analysis", model = model, tokenizer = tokenizer,return_all_scores=True)
    #res = classifier("good")
    #print(res)
    df = dataset.copy()
    #df = pd.DataFrame(columns = ['text', 'real_label', 'Negative','Neutral','Positive',])
    guess = []
    pos = []
    neg = []
    neu = []

    for text in dataset['tweet']:  
          res = classifier(text)[0]
          r = {res[0]['label']:res[0]['score'], res[1]['label']:res[1]['score'], res[2]['label']:res[2]['score']}
          pos.append(r['Positive'])
          neg.append(r['Negative'])
          neu.append(r['Neutral'])
    is_pass = False
    if len(pos) == len(neg) and len(pos) == len(neu):
      print("pass equal pos neg neu length")
      if len(pos) == dataset.shape[0]:
        print("pass dataset equality")
        is_pass = True
      else:
        print("fail dataset equality")
    else:
      print("fail equal pos neg neu length")
    
    df["Positive"] = pos
    df["Negative"] = neg
    df['Neutral'] = neu
    return df,is_pass

#df = labeller(directory,valid)
#display(df)

#df.to_csv("/notebooks/fyp/final_modelV2/valid_F2_lex_head.csv")

# %%
def filter(data):
  df = data
  df = df[df["tweet"].str.contains(" crypto | cryptocurrency | bitcoin | btc ")==True]
  return df
def clean(text):
  text = re.sub(r'@[A-Za-z0-9:]+', '',text) #removes @ mentions
  text = re.sub(r'#','',text) #remove #
  text = re.sub(r'RT[\s]+','',text) # remove RT
  text = re.sub(r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)', '', text) #removes links
  text = re.sub(r'\s*$','',text) #remove leading and trailing whitespace
  text = re.sub(r'^\s*','',text) #remove leading and leading whitespace
  text = re.sub(r'.+:', '',text) #remove username:
  return text

def clean_data(data):
  #data = data[data.language == 'en']
  data.replace("", np.nan, inplace=True) # replace empty string to nan 
  data.dropna(subset = ["tweet"], inplace=True) #remove all rows with nan tweet
  data['tweet'] = data['tweet'].apply(clean)
  data.replace("", np.nan, inplace=True) # replace empty string to nan 
  data.dropna(subset = ["tweet"], inplace=True) #remove all rows with nan twee
  data = data.drop_duplicates(subset = 'tweet', keep = False ) # remove duplicates and keep none 
  return data

#t = df_gold.iloc[0]['tweet']

# %%
df1 = pd.read_csv("/content/drive/MyDrive/fyp/fyp2/twint/twint1.csv")
df2 = pd.read_csv("/content/drive/MyDrive/fyp/fyp2/twint2/twint1.csv")
df3 = pd.read_csv("/content/drive/MyDrive/fyp/fyp2/twint3/twint1.csv")
df = pd.concat([df1,df2,df3])
print(df.shape[0])
df = df.drop_duplicates( keep='first', ignore_index=True)
print(df.shape[0])
display(df)
# Out:
# 675800
# 646970
#                     user_id                   id         username  \
# 0       1426115688339410945  1544510702961844226    bigwindollar_
# 1                 260006070  1544510681751470081   dondon_wontons
# 2       1149166543781212160  1544510677141884928      alejito_eth
# 3                 812751240  1544510665158967296      cryptopatel
# 4       1519473869802786816  1544510661488586753     sasboomstick
# ...                     ...                  ...              ...
# 646965  1532113040501514240  1564668267473633282  patiencemlengan
# 646966             14346923  1564668258330066945           raffel
# 646967            295325403  1564668226616799232       redcanoe63
# 646968            231796050  1564668219918532608      highertable
# 646969  1445821843395407879  1564668216139386880       dirtyonefo
#
#                      created_at        date      time  timezone  \
# 0       2022-07-06 02:37:01 UTC  2022-07-06  02:37:01         0
# 1       2022-07-06 02:36:56 UTC  2022-07-06  02:36:56         0
# 2       2022-07-06 02:36:55 UTC  2022-07-06  02:36:55         0
# 3       2022-07-06 02:36:52 UTC  2022-07-06  02:36:52         0
# 4       2022-07-06 02:36:51 UTC  2022-07-06  02:36:51         0
# ...                         ...         ...       ...       ...
# 646965  2022-08-30 17:35:59 UTC  2022-08-30  17:35:59         0
# 646966  2022-08-30 17:35:57 UTC  2022-08-30  17:35:57         0
# 646967  2022-08-30 17:35:50 UTC  2022-08-30  17:35:50         0
# 646968  2022-08-30 17:35:48 UTC  2022-08-30  17:35:48         0
# 646969  2022-08-30 17:35:47 UTC  2022-08-30  17:35:47         0
#
#                                                     tweet language  \
# 0       @yopicoin #yopicoin x1000 🚀 #yopinetwork #bitcoin      und
# 1                       You really can’t be nice to folks       en
# 2              @LH_btc @traderZ0 The queen shorting too 🥂       en
# 3          @BitcoinMagazine Always Bullish on #Bitcoin  ❤       en
# 4       @Eric_BIGfund Once trash tech algos stop leadi...       en
# ...                                                   ...      ...
# 646965  @George78772946 @tWeatherSA Have you heard abo...       en
# 646966  @MarekZee It’s amazing. The grinder is the fin...       en
# 646967  @btc_there4_i_am @SenTedCruz How's that retire...       en
# 646968  @markhendy @fieryseahorse @EssexPR Do you envi...       en
# 646969  @Paddy_Stash BTC seems to be having other plan...       en
#
#         retweets_count                                hashtags  retweet
# 0                    0  ['yopicoin', 'yopinetwork', 'bitcoin']    False
# 1                    0                                      []    False
# 2                    0                                      []    False
# 3                    0                             ['bitcoin']    False
# 4                    0                                      []    False
# ...                ...                                     ...      ...
# 646965               0                                      []    False
# 646966               0                                      []    False
# 646967               0                                      []    False
# 646968               0                                      []    False
# 646969               0                                      []    False
#
# [646970 rows x 12 columns]

# %%
files = glob.glob("/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/*.csv")
print(files)
df_list_temp = []
for file in files:
  temp1 = pd.read_csv(file)
  df_list_temp.append(temp1)
df_res = pd.concat(df_list_temp)
display(df_res)
# Out:
# ['/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_1.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_0.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_3.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_4.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_2.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_5.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_6.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_7.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_8.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_9.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_10.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_11.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_12.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_13.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_14.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_15.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_16.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_17.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_19.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_18.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_20.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_22.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_21.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_23.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_24.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_25.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_26.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_28.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy/lstm_data_cleaned_27.csv']
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0           95259         95362          114715            114763
# 1           95258         95361          114714            114762
# 2           95257         95360          114713            114761
# 3           95256         95359          114712            114760
# 4           95255         95358          114711            114759
# ...           ...           ...             ...               ...
# 99995       51959       2857143         3510913           3521338
# 99996       51958       2857142         3510912           3521337
# 99997       51957       2857141         3510909           3521334
# 99998       51956       2857140         3510908           3521333
# 99999       51955       2857139         3510907           3521332
#
#        Unnamed: 0.1.1.1.1                 date  \
# 0                     NaN  2021-05-28 08:30:40
# 1                     NaN  2021-05-28 08:30:41
# 2                     NaN  2021-05-28 08:30:45
# 3                     NaN  2021-05-28 08:30:49
# 4                     NaN  2021-05-28 08:31:16
# ...                   ...                  ...
# 99995                 NaN  2022-05-31 06:08:40
# 99996                 NaN  2022-05-31 06:08:50
# 99997                 NaN  2022-05-31 06:09:09
# 99998                 NaN  2022-05-31 06:09:24
# 99999                 NaN  2022-05-31 06:09:24
#
#                                                    tweet  is_retweet  \
# 0      🚀 🚀4,013 BTC (154,476,000 USD) move from unkno...       False
# 1      💵1,950 BTC (75,079,100 USD) move from unknown ...       False
# 2      ❗Initiative Q is an attempt by ex-PayPal guys ...       False
# 3      $BTC 🔴 - 36816.2 $  (-0.49 %)\n$ETH 🔴 - 2558 $...       False
# 4      The mobile app will be using.. a remote GRIDNE...       False
# ...                                                  ...         ...
# 99995  3X Long Ethereum Token (ETHBULL) went up 26.7 ...       False
# 99996  ELFUSDT Bear Alert!\n\n5X Volume\n      0.1609...       False
# 99997  BCHUSDT Bear Alert!\n\n10X Volume\n      198.6...       False
# 99998  PYRUSDT Bear Alert!\n\n5X Volume\n      4.57\n...       False
# 99999  BTC Short setup Binance Bybit Coinbase\n\n💥To ...       False
#
#        real_score vader_pseudo_label
# 0             NaN            Neutral
# 1             NaN            Neutral
# 2             NaN           Positive
# 3             NaN           Negative
# 4             NaN           Positive
# ...           ...                ...
# 99995         NaN            Neutral
# 99996         NaN           Negative
# 99997         NaN           Negative
# 99998         NaN           Negative
# 99999         NaN            Neutral
#
# [2869965 rows x 10 columns]

# %%
import math
def splitter(df_,out_dir,size):
  df = df_.copy()
  splits = math.ceil(df.shape[0] / size)
  for split in range(splits):
    start = 0 + (split)*size
    end = (split+1) * size
    if end > df.shape[0]:
      end = df.shape[0]
    df_o = df[start:end]
    df_o.to_csv(out_dir +"/lstm_data_cleaned_" + str(split) +".csv")

#print(df.shape[0])
#splitter(df_cleaned,"/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/cleaned",100000)

# %%
unlabelled_ = "/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/cleaned/lstm_data_cleaned_0.csv"
out_name = "labelled_lstm_data_0"
out_dir = "/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/labelled"
unlabelled = pd.read_csv(unlabelled_ ,lineterminator='\n')
display(unlabelled)
#df_labelled,is_pass = labeller("/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/final model",unlabelled)
#df_labelled.to_csv(out_dir + "/" + out_name + ".csv")
# Out:
#        Unnamed: 0              user_id                   id        username  \
# 0               1            260006070  1544510681751470081  dondon_wontons
# 1               2  1149166543781212160  1544510677141884928     alejito_eth
# 2               3            812751240  1544510665158967296     cryptopatel
# 3               4  1519473869802786816  1544510661488586753    sasboomstick
# 4               5             54897838  1544510658988875777    botelhofabio
# ...           ...                  ...                  ...             ...
# 99995      164507            295100681  1543518873097469954      berat_2019
# 99996      164508  1293821182282784776  1543518869494661123     cryptojobs3
# 99997      164509  1094255391641358337  1543518846203699201         learbtc
# 99998      164512   947260556658044928  1543518834891673601       yekkripto
# 99999      164513           2881307809  1543518830089195521      hillier_10
#
#                     created_at        date      time  timezone  \
# 0      2022-07-06 02:36:56 UTC  2022-07-06  02:36:56         0
# 1      2022-07-06 02:36:55 UTC  2022-07-06  02:36:55         0
# 2      2022-07-06 02:36:52 UTC  2022-07-06  02:36:52         0
# 3      2022-07-06 02:36:51 UTC  2022-07-06  02:36:51         0
# 4      2022-07-06 02:36:51 UTC  2022-07-06  02:36:51         0
# ...                        ...         ...       ...       ...
# 99995  2022-07-03 08:55:51 UTC  2022-07-03  08:55:51         0
# 99996  2022-07-03 08:55:50 UTC  2022-07-03  08:55:50         0
# 99997  2022-07-03 08:55:44 UTC  2022-07-03  08:55:44         0
# 99998  2022-07-03 08:55:42 UTC  2022-07-03  08:55:42         0
# 99999  2022-07-03 08:55:40 UTC  2022-07-03  08:55:40         0
#
#                                                    tweet language  \
# 0                      You really can’t be nice to folks       en
# 1                         _btc  The queen shorting too 🥂       en
# 2                           Always Bullish on Bitcoin  ❤       en
# 3      _BIGfund Once trash tech algos stop leading bi...       en
# 4                             Change this algorithm elon       en
# ...                                                  ...      ...
# 99995                               Bitcoin pizza stocks       en
# 99996  yes, there is a lot of scam pump and dump.. ne...       en
# 99997  _AIRmass  So him being long all the way from t...       en
# 99998  BollingerAlert !   - $WTC (948 sats) is over U...       en
# 99999  You still need to move your BTC on and off sid...       en
#
#        retweets_count                              hashtags  retweet
# 0                   0                                    []    False
# 1                   0                                    []    False
# 2                   0                           ['bitcoin']    False
# 3                   0                                    []    False
# 4                   0                                    []    False
# ...               ...                                   ...      ...
# 99995               0                                    []    False
# 99996               0                                    []    False
# 99997               0                                    []    False
# 99998               0  ['bollingeralert', 'crypto', 'coin']    False
# 99999               0                                    []    False
#
# [100000 rows x 13 columns]

# %%
def find_date_gaps(df):
  
  deltas = df['date'].diff()

  # Filter diffs (here days > 1, but could be seconds, hours, etc)
  gaps = deltas[deltas > timedelta(days=1)]

  # Print results
  print(f'{len(gaps)} gaps with average gap duration: {gaps.mean()}')
  for i, g in gaps.iteritems():
      gap_start = df['date'][i - 1]
      #print(type())
      end = gap_start + g.to_pytimedelta()
      print(f'Start: {datetime.strftime(gap_start, "%Y-%m-%d")} | '
            f'Duration: {str(g.to_pytimedelta())}')
      print(end)

#find_date_gaps(df_)

# %%
import glob
path = "/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/labelled"
path2 = "/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled"
path3 = "/content/drive/MyDrive/shafs stuff"
files = glob.glob(path + "/*.csv")
files2 = glob.glob(path2 + "/*.csv")
files3 = glob.glob(path3 + "/*.csv")
print(files2)
df_ls = []
df_ls2 = []
for file in files:
  df_temp = pd.read_csv(file,lineterminator='\n')
  df_ls.append(df_temp)
for file in files2:
  df_temp = pd.read_csv(file,lineterminator='\n')
  df_ls2.append(df_temp)

for file in files3:
  if file not in files2:
    print(file)
    df_temp = pd.read_csv(file,lineterminator='\n')
    df_ls2.append(df_temp)

df_o = pd.concat(df_ls)
df_o2 = pd.concat(df_ls2)
display(df_o)
display(df_o2)
# Out:
# ['/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_0.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_6.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_3.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_12.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_15.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_7.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_4.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_13.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_16.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_14.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_8.csv', '/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin_unused_clean_tweepy_labelled/unused_bitcoin_labelled_17.csv']
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_9.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_10.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_11.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_24.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_25.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_26.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_27.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_28.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_0.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_2.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_5.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_18.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_19.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_20.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_21.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_22.csv
# /content/drive/MyDrive/shafs stuff/unused_bitcoin_labelled_23.csv
#        Unnamed: 0  Unnamed: 0.1              user_id                   id  \
# 0               0        646474           3100174815  1564671267629834240
# 1               1        646476  1391254762499153922  1564671264446373889
# 2               2        646478  1271976542063620096  1564671251091693568
# 3               3        646480  1530613111992078339  1564671239817420800
# 4               4        646481  1402739758015520771  1564671237019668481
# ...           ...           ...                  ...                  ...
# 99995       99995        164507            295100681  1543518873097469954
# 99996       99996        164508  1293821182282784776  1543518869494661123
# 99997       99997        164509  1094255391641358337  1543518846203699201
# 99998       99998        164512   947260556658044928  1543518834891673601
# 99999       99999        164513           2881307809  1543518830089195521
#
#               username               created_at        date      time  \
# 0             duganist  2022-08-30 17:47:55 UTC  2022-08-30  17:47:55
# 1          zetamarkets  2022-08-30 17:47:54 UTC  2022-08-30  17:47:54
# 2      dficoastalmoons  2022-08-30 17:47:51 UTC  2022-08-30  17:47:51
# 3         carllyleryan  2022-08-30 17:47:48 UTC  2022-08-30  17:47:48
# 4       animalconcerts  2022-08-30 17:47:47 UTC  2022-08-30  17:47:47
# ...                ...                      ...         ...       ...
# 99995       berat_2019  2022-07-03 08:55:51 UTC  2022-07-03  08:55:51
# 99996      cryptojobs3  2022-07-03 08:55:50 UTC  2022-07-03  08:55:50
# 99997          learbtc  2022-07-03 08:55:44 UTC  2022-07-03  08:55:44
# 99998        yekkripto  2022-07-03 08:55:42 UTC  2022-07-03  08:55:42
# 99999       hillier_10  2022-07-03 08:55:40 UTC  2022-07-03  08:55:40
#
#        timezone                                              tweet language  \
# 0             0  FTX is a better version of Coinbase, a better ...       en
# 1             0                                _btc  we like Marty       en
# 2             0  _Archive until a certain political party gets ...       en
# 3             0                    $BTC bottom $13,200 October 9th       en
# 4             0  @_TheFigen Can confirm, this works.   How I re...       en
# ...         ...                                                ...      ...
# 99995         0                               Bitcoin pizza stocks       en
# 99996         0  yes, there is a lot of scam pump and dump.. ne...       en
# 99997         0  _AIRmass  So him being long all the way from t...       en
# 99998         0  BollingerAlert !   - $WTC (948 sats) is over U...       en
# 99999         0  You still need to move your BTC on and off sid...       en
#
#        retweets_count                              hashtags  retweet  \
# 0                   0                                    []    False
# 1                   0                                    []    False
# 2                   0                                    []    False
# 3                   1                                    []    False
# 4                   2                                    []    False
# ...               ...                                   ...      ...
# 99995               0                                    []    False
# 99996               0                                    []    False
# 99997               0                                    []    False
# 99998               0  ['bollingeralert', 'crypto', 'coin']    False
# 99999               0                                    []    False
#
#        Positive  Negative   Neutral
# 0      0.317264  0.067153  0.615583
# 1      0.164208  0.012036  0.823756
# 2      0.131345  0.120781  0.747873
# 3      0.109417  0.406267  0.484316
# 4      0.752398  0.010857  0.236744
# ...         ...       ...       ...
# 99995  0.626730  0.067146  0.306124
# 99996  0.192978  0.441299  0.365723
# 99997  0.315799  0.340557  0.343645
# 99998  0.350711  0.085211  0.564078
# 99999  0.250688  0.105930  0.643382
#
# [400308 rows x 17 columns]
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 0               0         18189           18205             21517
# 1               1         18188           18204             21513
# 2               2         18187           18203             21512
# 3               3         18186           18202             21511
# 4               4         18185           18201             21510
# ...           ...           ...             ...               ...
# 99995       99995       2340491         2876181           2884479
# 99996       99996       2340490         2876180           2884478
# 99997       99997       2340489         2876179           2884477
# 99998       99998       2340488         2876178           2884476
# 99999       99999       2353258         2892302           2900649
#
#        Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1                 date  \
# 0                 21524.0                   NaN  2021-02-05 10:52:04
# 1                 21520.0                   NaN  2021-02-05 10:52:26
# 2                 21519.0                   NaN  2021-02-05 10:53:49
# 3                 21518.0                   NaN  2021-02-05 10:54:52
# 4                 21517.0                   NaN  2021-02-05 10:57:05
# ...                   ...                   ...                  ...
# 99995                 NaN                   NaN  2022-04-21 15:37:05
# 99996                 NaN                   NaN  2022-04-21 15:37:06
# 99997                 NaN                   NaN  2022-04-21 15:37:06
# 99998                 NaN                   NaN  2022-04-21 15:37:07
# 99999                 NaN                   NaN  2022-04-21 15:37:07
#
#                                                    tweet  is_retweet  \
# 0      📖  Weekend Read 📖\n\nKeen to learn about crypt...       False
# 1      reddcoin rdd  to the moon altcoin turnreddcoin...       False
# 2      Bitcoin and ETH both have bullish setups for a...       False
# 3      $PERL 0.06.\nI have insisted that since 0.02 i...       False
# 4      Amazing 😍\nMonopoly Crypto cryptocurrency cryp...       False
# ...                                                  ...         ...
# 99995  🚨 JNL SERIES TRUST filed a 485BPOS SEC filing ...       False
# 99996  Crypto market Overview\n\n40.71%\nCHOP Season✔...       False
# 99997  This zesty faucet from @_bitcoiner is making m...       False
# 99998     🚨 TRADING ADVICE 🚨\n\nDon’t FOMO here 🤝bitcoin       False
# 99999  Pandagirl,  is gonna kick off her minting even...       False
#
#        real_score vader_pseudo_label  Positive  Negative   Neutral  \
# 0             NaN           Positive  0.415671  0.016809  0.567520
# 1             NaN            Neutral  0.562627  0.068772  0.368602
# 2             NaN           Positive  0.896245  0.024557  0.079198
# 3             NaN           Positive  0.649427  0.096485  0.254087
# 4             NaN           Positive  0.614979  0.007106  0.377915
# ...           ...                ...       ...       ...       ...
# 99995         NaN           Positive  0.183479  0.025951       NaN
# 99996         NaN           Positive  0.253531  0.309027       NaN
# 99997         NaN           Positive  0.257304  0.042683       NaN
# 99998         NaN            Neutral  0.053780  0.038835       NaN
# 99999         NaN           Positive  0.468534  0.006406       NaN
#
#        Unnamed: 0.2  Neutral\r
# 0               NaN        NaN
# 1               NaN        NaN
# 2               NaN        NaN
# 3               NaN        NaN
# 4               NaN        NaN
# ...             ...        ...
# 99995       36817.0   0.790571
# 99996       36816.0   0.437442
# 99997       36815.0   0.700013
# 99998       36814.0   0.907385
# 99999       49557.0   0.525060
#
# [2869965 rows x 16 columns]

# %%
#check timezones
timezone_ls = []
for i in df_o['timezone']:
  if i not in timezone_ls:
    timezone_ls.append(i)
    print(i)
print("all the timezones are: " , timezone_ls)
if len(timezone_ls) == 1:
  print("all same timezone")
else:
  print("all not same timezone")
# Out:
# 0
# all the timezones are:  [0]
# all same timezone

# %%
df1 = df_o.copy()
df2 = df_o2.copy()
#display(pytz.all_timezones) 
df1['created_at'] = pd.to_datetime(df1['created_at'], format='%Y-%m-%d %H:%M:%S %Z')
df2['date'] = pd.to_datetime(df2['date'], format='%Y-%m-%d %H:%M:%S')


#convert from utc to est as bitcoin data is in est
df2['date'] = df2['date'].dt.tz_localize("GMT").dt.tz_convert('est')
df1['created_at'] = df1['created_at'].dt.tz_convert('est')

#print("bob 34")
df1 = df1[['created_at','tweet','Positive','Neutral','Negative']]
df1 = df1.rename(columns={"created_at": "date"})
df2 = df2[['date','tweet','Positive','Neutral','Negative']]
#display(df1)
#display(df2)
df = pd.concat([df1,df2])
df = df.drop_duplicates(subset=['date', 'tweet'], keep='first')
print(df1.shape[0],'  ',df2.shape[0],'  ',df1.shape[0]+df2.shape[0]),
display(df)

#df['date'] = df['date'].apply(lambda t: t.strftime('%Y-%m-%d %H'))
df['date'] = df['date'].apply(lambda t: t.strftime('%Y-%m-%d'))


df_pos = df.groupby([df['date']])['Positive'].mean().to_frame()
df_neu = df.groupby([df['date']])['Neutral'].mean().to_frame()
df_neg = df.groupby([df['date']])['Negative'].mean().to_frame()
#df_count = df.groupby([df['date']]).count()[['date','tweet']]
df_count = df.groupby([df['date']])['tweet'].count().to_frame()
df = df_neg
df['Neutral'] = df_neu['Neutral']
df['Positive'] = df_pos['Positive']
df['count'] = df_count['tweet']
display(df)
print(df.shape[0])
# Out:
# 400308    2869965    3270273
#                            date  \
# 0     2022-08-30 12:47:55-05:00
# 1     2022-08-30 12:47:54-05:00
# 2     2022-08-30 12:47:51-05:00
# 3     2022-08-30 12:47:48-05:00
# 4     2022-08-30 12:47:47-05:00
# ...                         ...
# 99995 2022-04-21 10:37:05-05:00
# 99996 2022-04-21 10:37:06-05:00
# 99997 2022-04-21 10:37:06-05:00
# 99998 2022-04-21 10:37:07-05:00
# 99999 2022-04-21 10:37:07-05:00
#
#                                                    tweet  Positive   Neutral  \
# 0      FTX is a better version of Coinbase, a better ...  0.317264  0.615583
# 1                                    _btc  we like Marty  0.164208  0.823756
# 2      _Archive until a certain political party gets ...  0.131345  0.747873
# 3                        $BTC bottom $13,200 October 9th  0.109417  0.484316
# 4      @_TheFigen Can confirm, this works.   How I re...  0.752398  0.236744
# ...                                                  ...       ...       ...
# 99995  🚨 JNL SERIES TRUST filed a 485BPOS SEC filing ...  0.183479       NaN
# 99996  Crypto market Overview\n\n40.71%\nCHOP Season✔...  0.253531       NaN
# 99997  This zesty faucet from @_bitcoiner is making m...  0.257304       NaN
# 99998     🚨 TRADING ADVICE 🚨\n\nDon’t FOMO here 🤝bitcoin  0.053780       NaN
# 99999  Pandagirl,  is gonna kick off her minting even...  0.468534       NaN
#
#        Negative
# 0      0.067153
# 1      0.012036
# 2      0.120781
# 3      0.406267
# 4      0.010857
# ...         ...
# 99995  0.025951
# 99996  0.309027
# 99997  0.042683
# 99998  0.038835
# 99999  0.006406
#
# [3170273 rows x 5 columns]
#             Negative   Neutral  Positive  count
# date
# 2021-02-05  0.090510  0.468611  0.440879   1875
# 2021-02-06  0.087718  0.457682  0.454601   2586
# 2021-02-07  0.076292  0.513266  0.410442   2183
# 2021-02-08  0.074992  0.408843  0.516166   5455
# 2021-02-09  0.079048  0.440184  0.480768   3417
# ...              ...       ...       ...    ...
# 2022-07-25  0.181530  0.452563  0.365908  26122
# 2022-07-26  0.184805  0.447625  0.367570  26304
# 2022-07-27  0.170858  0.457783  0.371359  27313
# 2022-07-28  0.173140  0.447520  0.379340  11760
# 2022-08-30  0.178000  0.447730  0.374270   8313
#
# [179 rows x 4 columns]
# 179

# %%
import pandas as pd
import requests
import json

def fetch_daily_data(symbol):
  pair_split = symbol.split('/')  # symbol must be in format XXX/XXX ie. BTC/EUR
  symbol = pair_split[0] + '-' + pair_split[1]
  url = f'https://api.pro.coinbase.com/products/{symbol}/candles?granularity=86400'
  response = requests.get(url)
  if response.status_code == 200:  # check to make sure the response from server is good
    data = pd.DataFrame(json.loads(response.text), columns=['unix', 'low', 'high', 'open', 'close', 'volume'])
    data['date'] = pd.to_datetime(data['unix'], unit='s')  # convert to a readable date
    data['vol_fiat'] = data['volume'] * data['close']      # multiply the BTC volume by closing price to approximate fiat volume

# if we failed to get any data, print an error...otherwise write the file
    if data is None:
      print("Did not return any data from Coinbase for this symbol")
    else:
      #data.to_csv(f'Coinbase_{pair_split[0] + pair_split[1]}_dailydata.csv', index=False)
      return data
  else:
    print("Did not receieve OK response from Coinbase API")

# %%
#bit_price = pd.read_csv('/content/drive/MyDrive/fyp/fyp2/Bitstamp_BTCUSD_d.csv')
pair = "BTC/USD"
#bit_price = fetch_daily_data(pair)
bit_price = pd.read_csv("/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/dataset/bitcoin price/Gemini_BTCUSD_d.csv")
#bit_price = bit_price.reset_index(level=0)
display(bit_price)

bit_price['date'] = pd.to_datetime(bit_price['date'], format='%d/%m/%Y %H:%M')
#bit_price['date2'] = pd.to_datetime(bit_price['date'], unit='s')
bit_price = bit_price[['date', 'close']]
bit_price['date'] = bit_price['date'].apply(lambda t: t.strftime('%Y-%m-%d'))
#bit_price['date2'] = bit_price['date']
bit_price.set_index('date',inplace = True)
#bit_price = bit_price.rename(columns={'date2':'date'})
display(bit_price)
# Out:
#               unix              date   symbol      open      high       low  \
# 0     1.662180e+12  03/09/2022 04:00  BTC/USD  19898.38  19967.65  19665.83
# 1     1.662090e+12  02/09/2022 04:00  BTC/USD  20165.78  20434.56  19764.91
# 2     1.662000e+12  01/09/2022 04:00  BTC/USD  20022.02  20235.81  19568.96
# 3     1.661920e+12  31/08/2022 04:00  BTC/USD  20413.79  20484.98  19877.66
# 4     1.661830e+12  30/08/2022 04:00  BTC/USD  20268.62  20561.70  19549.66
# ...            ...               ...      ...       ...       ...       ...
# 2518  1.444622e+09  12/10/2015 04:00  BTC/USD    248.98    248.98    245.75
# 2519  1.444536e+09  11/10/2015 04:00  BTC/USD    246.30    249.50    245.96
# 2520  1.444450e+09  10/10/2015 04:00  BTC/USD    245.51    246.30    244.60
# 2521  1.444363e+09  09/10/2015 04:00  BTC/USD    243.60    249.97    243.60
# 2522  1.444277e+09  08/10/2015 04:00  BTC/USD      0.00    245.00      0.00
#
#          close   Volume BTC    Volume USD
# 0     19826.17   317.296150  6.290767e+06
# 1     19898.38   984.727228  1.959448e+07
# 2     20165.78  1843.976726  3.718523e+07
# 3     20022.02  1269.857927  2.542512e+07
# 4     20413.79  1519.798134  3.102484e+07
# ...        ...          ...           ...
# 2518    245.75    71.047743  1.745998e+04
# 2519    248.98    22.747091  5.663571e+03
# 2520    246.30    30.870549  7.603416e+03
# 2521    245.51    61.587068  1.512024e+04
# 2522    243.60    34.754703  8.466246e+03
#
# [2523 rows x 9 columns]
#                close
# date
# 2022-09-03  19826.17
# 2022-09-02  19898.38
# 2022-09-01  20165.78
# 2022-08-31  20022.02
# 2022-08-30  20413.79
# ...              ...
# 2015-10-12    245.75
# 2015-10-11    248.98
# 2015-10-10    246.30
# 2015-10-09    245.51
# 2015-10-08    243.60
#
# [2523 rows x 1 columns]

# %%
#df_merged = df.merge(bit_price, left_index=True, right_index=True)
df_merged = pd.merge(bit_price, df, left_index=True, right_index=True)
display(df)
display(bit_price)
display(df_merged)
# Out:
#             Negative   Neutral  Positive  count
# date
# 2021-02-05  0.090510  0.468611  0.440879   1875
# 2021-02-06  0.087718  0.457682  0.454601   2586
# 2021-02-07  0.076292  0.513266  0.410442   2183
# 2021-02-08  0.074992  0.408843  0.516166   5455
# 2021-02-09  0.079048  0.440184  0.480768   3417
# ...              ...       ...       ...    ...
# 2022-07-25  0.181530  0.452563  0.365908  26122
# 2022-07-26  0.184805  0.447625  0.367570  26304
# 2022-07-27  0.170858  0.457783  0.371359  27313
# 2022-07-28  0.173140  0.447520  0.379340  11760
# 2022-08-30  0.178000  0.447730  0.374270   8313
#
# [179 rows x 4 columns]
#                close
# date
# 2022-09-03  19826.17
# 2022-09-02  19898.38
# 2022-09-01  20165.78
# 2022-08-31  20022.02
# 2022-08-30  20413.79
# ...              ...
# 2015-10-12    245.75
# 2015-10-11    248.98
# 2015-10-10    246.30
# 2015-10-09    245.51
# 2015-10-08    243.60
#
# [2523 rows x 1 columns]
#                close  Negative   Neutral  Positive  count
# date
# 2022-08-30  20413.79  0.178000  0.447730  0.374270   8313
# 2022-07-28  23921.33  0.173140  0.447520  0.379340  11760
# 2022-07-27  23126.10  0.170858  0.457783  0.371359  27313
# 2022-07-26  21076.57  0.184805  0.447625  0.367570  26304
# 2022-07-25  21147.15  0.181530  0.452563  0.365908  26122
# ...              ...       ...       ...       ...    ...
# 2021-02-09  46309.88  0.079048  0.440184  0.480768   3417
# 2021-02-08  46653.50  0.074992  0.408843  0.516166   5455
# 2021-02-07  38107.34  0.076292  0.513266  0.410442   2183
# 2021-02-06  38897.95  0.087718  0.457682  0.454601   2586
# 2021-02-05  39415.76  0.090510  0.468611  0.440879   1875
#
# [179 rows x 5 columns]

# %%
df = df_merged.copy()
df.index = pd.to_datetime(df.index)
df = df.sort_index()
df_ = df.reset_index()
find_date_gaps(df_)
#display(df)
#print(type(df_["date"].iloc[0]))
# create new datetime index based on specified range
daterng_all = pd.date_range(start=df_["date"].iloc[0], end=df_["date"].iloc[-1])
print("BOB")
display(daterng_all)
# create rows with missing intervals and fill missing data
display(df)
df_test = df.reindex(daterng_all, fill_value=np.nan)
display(df_test)
df = df_test.reset_index()
df = df.rename(columns={'index': 'date'})
#df = df.rename_axis('index1').reset_index()

display(df)
find_date_gaps(df)
# Out:
# 38 gaps with average gap duration: 11 days 08:12:37.894736842
# Start: 2021-02-10 | Duration: 3 days, 0:00:00
# 2021-02-13 00:00:00
# Start: 2021-02-15 | Duration: 3 days, 0:00:00
# 2021-02-18 00:00:00
# Start: 2021-02-19 | Duration: 3 days, 0:00:00
# 2021-02-22 00:00:00
# Start: 2021-02-22 | Duration: 6 days, 0:00:00
# 2021-02-28 00:00:00
# Start: 2021-02-28 | Duration: 11 days, 0:00:00
# 2021-03-11 00:00:00
# Start: 2021-03-12 | Duration: 24 days, 0:00:00
# 2021-04-05 00:00:00
# Start: 2021-04-12 | Duration: 5 days, 0:00:00
# 2021-04-17 00:00:00
# Start: 2021-04-24 | Duration: 31 days, 0:00:00
# 2021-05-25 00:00:00
# Start: 2021-05-28 | Duration: 26 days, 0:00:00
# 2021-06-23 00:00:00
# Start: 2021-06-23 | Duration: 9 days, 0:00:00
# 2021-07-02 00:00:00
# Start: 2021-07-05 | Duration: 10 days, 0:00:00
# 2021-07-15 00:00:00
# Start: 2021-07-30 | Duration: 5 days, 0:00:00
# 2021-08-04 00:00:00
# Start: 2021-08-09 | Duration: 5 days, 0:00:00
# 2021-08-14 00:00:00
# Start: 2021-08-21 | Duration: 2 days, 0:00:00
# 2021-08-23 00:00:00
# Start: 2021-08-26 | Duration: 15 days, 0:00:00
# 2021-09-10 00:00:00
# Start: 2021-09-10 | Duration: 38 days, 0:00:00
# 2021-10-18 00:00:00
# Start: 2021-10-23 | Duration: 4 days, 0:00:00
# 2021-10-27 00:00:00
# Start: 2021-10-29 | Duration: 6 days, 0:00:00
# 2021-11-04 00:00:00
# Start: 2021-11-06 | Duration: 5 days, 0:00:00
# 2021-11-11 00:00:00
# Start: 2021-11-12 | Duration: 6 days, 0:00:00
# 2021-11-18 00:00:00
# Start: 2021-11-19 | Duration: 5 days, 0:00:00
# 2021-11-24 00:00:00
# Start: 2021-11-26 | Duration: 15 days, 0:00:00
# 2021-12-11 00:00:00
# Start: 2021-12-11 | Duration: 6 days, 0:00:00
# 2021-12-17 00:00:00
# Start: 2021-12-17 | Duration: 12 days, 0:00:00
# 2021-12-29 00:00:00
# Start: 2021-12-30 | Duration: 12 days, 0:00:00
# 2022-01-11 00:00:00
# Start: 2022-01-14 | Duration: 5 days, 0:00:00
# 2022-01-19 00:00:00
# Start: 2022-01-22 | Duration: 18 days, 0:00:00
# 2022-02-09 00:00:00
# Start: 2022-02-09 | Duration: 5 days, 0:00:00
# 2022-02-14 00:00:00
# Start: 2022-02-18 | Duration: 12 days, 0:00:00
# 2022-03-02 00:00:00
# Start: 2022-03-02 | Duration: 4 days, 0:00:00
# 2022-03-06 00:00:00
# Start: 2022-03-10 | Duration: 4 days, 0:00:00
# 2022-03-14 00:00:00
# Start: 2022-03-24 | Duration: 20 days, 0:00:00
# 2022-04-13 00:00:00
# Start: 2022-04-22 | Duration: 5 days, 0:00:00
# 2022-04-27 00:00:00
# Start: 2022-05-02 | Duration: 8 days, 0:00:00
# 2022-05-10 00:00:00
# Start: 2022-05-13 | Duration: 9 days, 0:00:00
# 2022-05-22 00:00:00
# Start: 2022-06-04 | Duration: 22 days, 0:00:00
# 2022-06-26 00:00:00
# Start: 2022-07-05 | Duration: 19 days, 0:00:00
# 2022-07-24 00:00:00
# Start: 2022-07-28 | Duration: 33 days, 0:00:00
# 2022-08-30 00:00:00
# BOB
# DatetimeIndex(['2021-02-05', '2021-02-06', '2021-02-07', '2021-02-08',
#                '2021-02-09', '2021-02-10', '2021-02-11', '2021-02-12',
#                '2021-02-13', '2021-02-14',
#                ...
#                '2022-08-21', '2022-08-22', '2022-08-23', '2022-08-24',
#                '2022-08-25', '2022-08-26', '2022-08-27', '2022-08-28',
#                '2022-08-29', '2022-08-30'],
#               dtype='datetime64[ns]', length=572, freq='D')
#                close  Negative   Neutral  Positive  count
# date
# 2021-02-05  39415.76  0.090510  0.468611  0.440879   1875
# 2021-02-06  38897.95  0.087718  0.457682  0.454601   2586
# 2021-02-07  38107.34  0.076292  0.513266  0.410442   2183
# 2021-02-08  46653.50  0.074992  0.408843  0.516166   5455
# 2021-02-09  46309.88  0.079048  0.440184  0.480768   3417
# ...              ...       ...       ...       ...    ...
# 2022-07-25  21147.15  0.181530  0.452563  0.365908  26122
# 2022-07-26  21076.57  0.184805  0.447625  0.367570  26304
# 2022-07-27  23126.10  0.170858  0.457783  0.371359  27313
# 2022-07-28  23921.33  0.173140  0.447520  0.379340  11760
# 2022-08-30  20413.79  0.178000  0.447730  0.374270   8313
#
# [179 rows x 5 columns]
#                close  Negative   Neutral  Positive   count
# 2021-02-05  39415.76  0.090510  0.468611  0.440879  1875.0
# 2021-02-06  38897.95  0.087718  0.457682  0.454601  2586.0
# 2021-02-07  38107.34  0.076292  0.513266  0.410442  2183.0
# 2021-02-08  46653.50  0.074992  0.408843  0.516166  5455.0
# 2021-02-09  46309.88  0.079048  0.440184  0.480768  3417.0
# ...              ...       ...       ...       ...     ...
# 2022-08-26       NaN       NaN       NaN       NaN     NaN
# 2022-08-27       NaN       NaN       NaN       NaN     NaN
# 2022-08-28       NaN       NaN       NaN       NaN     NaN
# 2022-08-29       NaN       NaN       NaN       NaN     NaN
# 2022-08-30  20413.79  0.178000  0.447730  0.374270  8313.0
#
# [572 rows x 5 columns]
#           date     close  Negative   Neutral  Positive   count
# 0   2021-02-05  39415.76  0.090510  0.468611  0.440879  1875.0
# 1   2021-02-06  38897.95  0.087718  0.457682  0.454601  2586.0
# 2   2021-02-07  38107.34  0.076292  0.513266  0.410442  2183.0
# 3   2021-02-08  46653.50  0.074992  0.408843  0.516166  5455.0
# 4   2021-02-09  46309.88  0.079048  0.440184  0.480768  3417.0
# ..         ...       ...       ...       ...       ...     ...
# 567 2022-08-26       NaN       NaN       NaN       NaN     NaN
# 568 2022-08-27       NaN       NaN       NaN       NaN     NaN
# 569 2022-08-28       NaN       NaN       NaN       NaN     NaN
# 570 2022-08-29       NaN       NaN       NaN       NaN     NaN
# 571 2022-08-30  20413.79  0.178000  0.447730  0.374270  8313.0
#
# [572 rows x 6 columns]
# 0 gaps with average gap duration: NaT

# %%
#display(daterng_all)
display(df)
for i in df['date']:
  print(type(i))
# Out:
#           date     close  Negative   Neutral  Positive   count
# 0   2021-02-05  39415.76  0.090510  0.468611  0.440879  1875.0
# 1   2021-02-06  38897.95  0.087718  0.457682  0.454601  2586.0
# 2   2021-02-07  38107.34  0.076292  0.513266  0.410442  2183.0
# 3   2021-02-08  46653.50  0.074992  0.408843  0.516166  5455.0
# 4   2021-02-09  46309.88  0.079048  0.440184  0.480768  3417.0
# ..         ...       ...       ...       ...       ...     ...
# 567 2022-08-26       NaN       NaN       NaN       NaN     NaN
# 568 2022-08-27       NaN       NaN       NaN       NaN     NaN
# 569 2022-08-28       NaN       NaN       NaN       NaN     NaN
# 570 2022-08-29       NaN       NaN       NaN       NaN     NaN
# 571 2022-08-30  20413.79  0.178000  0.447730  0.374270  8313.0
#
# [572 rows x 6 columns]
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
# https://youtu.be/tepxdcepTbY
"""
@author: Sreenivas Bhattiprolu
Code tested on Tensorflow: 2.2.0
    Keras: 2.4.3
dataset: https://finance.yahoo.com/quote/GE/history/
Also try S&P: https://finance.yahoo.com/quote/%5EGSPC/history?p=%5EGSPC
"""
#base code taken from above but modified to fit my needs

import tensorflow
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
#from datetime import datetime

#Read the csv file
#df = pd.read_csv('data/GE.csv')
def create_scaler(df):
  cols = list(df)[1:6]
  df_ = df[cols].astype(float)
  scaler = StandardScaler()
  scaler = scaler.fit(df_)
  return scaler

def create_model(df,num_of_epoch=1000,n_past = 5,n_future = 1,scaler = None,valid_split = 0.1):
  #print(df.head()) #7 columns, including the Date. 

  #Separate dates for future plotting
  train_dates = pd.to_datetime(df['date'])
  #print(train_dates.tail(15)) #Check last few dates. 

  #Variables for training
  cols = list(df)[1:6]
  #Date and volume columns are not used in training. 
  #print(cols) #['Open', 'High', 'Low', 'Close', 'Adj Close']


  #New dataframe with only training data - 5 columns
  df_for_training = df[cols].astype(float)

  # df_for_plot=df_for_training.tail(5000)
  # df_for_plot.plot.line()

  #LSTM uses sigmoid and tanh that are sensitive to magnitude so values need to be normalized
  # normalize the dataset
  if scaler == None:
    scaler = StandardScaler()
    scaler = scaler.fit(df_for_training)
  df_for_training_scaled = scaler.transform(df_for_training)
  #print("scaled df is below")
  #display(df_for_training_scaled)

  #As required for LSTM networks, we require to reshape an input data into n_samples x timesteps x n_features. 
  #In this example, the n_features is 5. We will make timesteps = 14 (past days data used for training). 

  #Empty lists to be populated using formatted training data
  trainX = []
  trainY = []

  #n_future = 1   # Number of days we want to look into the future based on the past days.
  #n_past = 5  # Number of past days we want to use to predict the future.

  #Reformat input data into a shape: (n_samples x timesteps x n_features)
  #In my example, my df_for_training_scaled has a shape (12823, 5)
  #12823 refers to the number of data points and 5 refers to the columns (multi-variables).
  for i in range(n_past, len(df_for_training_scaled) - n_future +1):
      x = df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]]
      y = df_for_training_scaled[i + n_future - 1:i + n_future, 0]
      if not np.isnan(x).any() and not np.isnan(y).any():
        #display(x)
        #display(y)
        trainX.append(x)
        trainY.append(y)
  #print("size of trainX: ", len(trainX))
  trainX, trainY = np.array(trainX), np.array(trainY)

  #print('trainX shape == {}.'.format(trainX.shape))
  #print('trainY shape == {}.'.format(trainY.shape))

  #In my case, trainX has a shape (12809, 14, 5). 
  #12809 because we are looking back 14 days (12823 - 14 = 12809). 
  #Remember that we cannot look back 14 days until we get to the 15th day. 
  #Also, trainY has a shape (12809, 1). Our model only predicts a single value, but 
  #it needs multiple variables (5 in my example) to make this prediction. 
  #This is why we can only predict a single day after our training, the day after where our data ends.
  #To predict more days in future, we need all the 5 variables which we do not have. 
  #We need to predict all variables if we want to do that. 

  # define the Autoencoder model

  model = Sequential()
  model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
  model.add(LSTM(32, activation='relu', return_sequences=False))
  model.add(Dropout(0.2))
  model.add(Dense(trainY.shape[1]))

  model.compile(optimizer='adam', loss='mse')
  #model.summary()


  # fit the model
  size = len(trainX)
  #print(size)
  valid_size = int(round(size*valid_split))
  #print(valid_size)
  trainX_ = trainX[0:size -valid_size]
  trainY_ = trainY[0:size -valid_size]
  validX = trainX[size -valid_size:size]
  validY = trainY[size -valid_size:size]

  #print("lengthsss")
  #print(len(trainX_))
  #print(len(validY))

  #history = model.fit(trainX, trainY, epochs=num_of_epoch, batch_size=16, validation_split=0.1, verbose=1)
  history = model.fit(trainX_, trainY_, epochs=num_of_epoch, batch_size=16, validation_data=(validX,validY), verbose=0)

  #plt.plot(history.history['loss'], label='Training loss')
  #plt.plot(history.history['val_loss'], label='Validation loss')
  #plt.legend()
  #print(trainX[0])
  #print(len(trainX[0]))
  return model,scaler,(trainX_, trainY_),(validX,validY)
display(df)
model,scaler,t,v = create_model(df,num_of_epoch =20, n_past = 2)
# Out:
#           date     close  Negative   Neutral  Positive   count
# 0   2021-02-05  39415.76  0.090510  0.468611  0.440879  1875.0
# 1   2021-02-06  38897.95  0.087718  0.457682  0.454601  2586.0
# 2   2021-02-07  38107.34  0.076292  0.513266  0.410442  2183.0
# 3   2021-02-08  46653.50  0.074992  0.408843  0.516166  5455.0
# 4   2021-02-09  46309.88  0.079048  0.440184  0.480768  3417.0
# ..         ...       ...       ...       ...       ...     ...
# 567 2022-08-26       NaN       NaN       NaN       NaN     NaN
# 568 2022-08-27       NaN       NaN       NaN       NaN     NaN
# 569 2022-08-28       NaN       NaN       NaN       NaN     NaN
# 570 2022-08-29       NaN       NaN       NaN       NaN     NaN
# 571 2022-08-30  20413.79  0.178000  0.447730  0.374270  8313.0
#
# [572 rows x 6 columns]
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
def update__(df,train,valid,num_of_epoch = 1,n_past = 5,n_future = 1,scaler = None):

  train_dates = pd.to_datetime(df['date'])
  #print(train_dates.tail(15)) #Check last few dates. 

  #Variables for training
  cols = list(df)[1:6]
  #Date and volume columns are not used in training. 
  #print(cols) #['Open', 'High', 'Low', 'Close', 'Adj Close']


  #New dataframe with only training data - 5 columns
  df_for_training = df[cols].astype(float)

  # df_for_plot=df_for_training.tail(5000)
  # df_for_plot.plot.line()

  #LSTM uses sigmoid and tanh that are sensitive to magnitude so values need to be normalized
  # normalize the dataset
  if scaler == None:
    scaler = StandardScaler()
    scaler = scaler.fit(df_for_training)
  df_for_training_scaled = scaler.transform(df_for_training)
  display(df_for_training_scaled)

  #As required for LSTM networks, we require to reshape an input data into n_samples x timesteps x n_features. 
  #In this example, the n_features is 5. We will make timesteps = 14 (past days data used for training). 

  #Empty lists to be populated using formatted training data
  trainX = []
  trainY = []

  #n_future = 1   # Number of days we want to look into the future based on the past days.
  #n_past = 5  # Number of past days we want to use to predict the future.

  #Reformat input data into a shape: (n_samples x timesteps x n_features)
  #In my example, my df_for_training_scaled has a shape (12823, 5)
  #12823 refers to the number of data points and 5 refers to the columns (multi-variables).
  for i in range(n_past, len(df_for_training_scaled) - n_future +1):
      x = df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]]
      y = df_for_training_scaled[i + n_future - 1:i + n_future, 0]
      if not np.isnan(x).any() and not np.isnan(y).any():
        #display(x)
        #display(y)
        trainX.append(x)
        trainY.append(y)

  trainX, trainY = np.array(trainX), np.array(trainY)
  
  #history = model.fit(trainX, trainY, epochs=num_of_epoch, batch_size=16, validation_split=0.1, verbose=1)
  history = model.fit(trainX, trainY, epochs=num_of_epoch, batch_size=16, validation_data=(validX,validY), verbose=0)
  model.reset_states()
  #plt.plot(history.history['loss'], label='Training loss')
  #plt.plot(history.history['val_loss'], label='Validation loss')
  #plt.legend()
  return model,scaler

# %%
def update(model,df,next_day_price,train,valid,num_of_epoch = 1,n_past = 5,n_future = 1,scaler = None):
  cols = list(df)[1:6]
  df_fake = pd.DataFrame(columns=cols)
  new_fake_row = {cols[0]:next_day_price,cols[1]:0,cols[2]:0,cols[3]:0,cols[4]:0}
  df_fake = df_fake.append(new_fake_row,ignore_index=True)
  #display(df_fake)
  #print(cols) #['Open', 'High', 'Low', 'Close', 'Adj Close']


  #New dataframe with only training data - 5 columns
  df_for_training = df[cols].astype(float)

  # df_for_plot=df_for_training.tail(5000)
  # df_for_plot.plot.line()

  #LSTM uses sigmoid and tanh that are sensitive to magnitude so values need to be normalized
  # normalize the dataset
  if scaler == None:
    scaler = StandardScaler()
    scaler = scaler.fit(df_for_training)
  df_for_training_scaled = scaler.transform(df_for_training)
  df_future_scaled = scaler.transform(df_fake)
  #display(df_for_training_scaled)
  #display(df_future_scaled)


  trainX = df_for_training_scaled
  trainY = df_future_scaled[0][0]#

  trainX_, trainY_ = np.array(trainX), np.array(trainY)
  trainX_ = np.expand_dims(trainX_, axis=0)
  trainY_ = np.expand_dims(trainY_, axis=0)
  trainY_ = np.expand_dims(trainY_, axis=0)
  
  trainX = np.concatenate((train[0],trainX_))
  trainY = np.concatenate((train[1],trainY_))

  
  #history = model.fit(trainX, trainY, epochs=num_of_epoch, batch_size=16, validation_split=0.1, verbose=1)
  history = model.fit(trainX, trainY, epochs=num_of_epoch, batch_size=16, validation_data=(valid[0],valid[1]), verbose=0)
  model.reset_states()
  #plt.plot(history.history['loss'], label='Training loss')
  #plt.plot(history.history['val_loss'], label='Validation loss')
  #plt.legend()
  return model,scaler,(trainX, trainY)

#print(t)
model_ = update(model,df[0:2],46000,t,v,scaler = scaler,n_past = 2)

# %%
def predict(model,df,pastdays = 5,scaler=None):
  
  cols = list(df)[1:6]
  #print(cols)
  df_for_training = df.tail(pastdays)
  df_for_training = df[cols].astype(float).tail(pastdays)
  if scaler == None:
    scaler = StandardScaler()
    scaler = scaler.fit(df_for_training)
  #display(df_for_training)
  df_for_training_scaled = scaler.transform(df_for_training)
  #print("scaled below")
  #display(df_for_training_scaled)
  x = np.array(df_for_training_scaled)
  #print(x)
  n_days_for_prediction = 7
  x = np.expand_dims(x, axis=0)
  #x = x.reshape(1, 1, len(x))
  prediction_raw = model.predict(x,batch_size = 1)
  prediction_copies = np.repeat(prediction_raw, len(cols), axis=-1)

  price_pred = scaler.inverse_transform(prediction_copies)[:,0]
  return price_pred,prediction_raw

display(df[:6])
price,pred = predict(model,df[:5],scaler = scaler,pastdays =2 )
print(price)
print(pred)
# Out:
#         date     close  Negative   Neutral  Positive   count
# 0 2021-02-05  39415.76  0.090510  0.468611  0.440879  1875.0
# 1 2021-02-06  38897.95  0.087718  0.457682  0.454601  2586.0
# 2 2021-02-07  38107.34  0.076292  0.513266  0.410442  2183.0
# 3 2021-02-08  46653.50  0.074992  0.408843  0.516166  5455.0
# 4 2021-02-09  46309.88  0.079048  0.440184  0.480768  3417.0
# 5 2021-02-10  45513.94  0.083423  0.465922  0.450655  2674.0
# [50639.184]
# [[0.7637946]]

# %%
def experiment(df_train,df_predict,past_days,bit_price,n_future = 1,update_epoch_num =1 ):
  n_past = past_days
  df_full = pd.concat([df_train,df_predict])
  df_curr = df_train
  #display(df_train)
  #display(df_predict)
  #display(df_full)
  scaler = create_scaler(df_full)
  model,scaler_,train,valid = create_model(df_train,scaler = scaler,n_past=past_days,num_of_epoch = 200)
  predictions = pd.DataFrame(columns=['date', 'real','pred' ])
  bit_price.index = pd.to_datetime(bit_price.index)
  df_predict_ls = []

  for i in range(past_days,len(df_predict)+1):
    start = i - past_days
    end = i 
    x = df_predict[start:end].copy()
    #print(x.isnull().values.any())
    #display(x)
    if not x.isnull().values.any():
      df_predict_ls.append(x)

  #print("list ting")
  #print(df_predict_ls)
  for idx,row in enumerate(df_predict_ls):
    last_day_data = row.copy().tail(1)
    #print("check check check")
    #display(row)
    date = last_day_data['date'].iloc[0] + timedelta(days = 1)
    real_price = bit_price.loc[date]['close']
    price_pred = predict(model,row,pastdays = past_days,scaler = scaler)
    new_row = {'date':date, 'real':real_price, 'pred':price_pred[0][0]}
    predictions = predictions.append(new_row,ignore_index=True)
    model,scaler__,train = update(model,row,real_price,train,valid,n_past=past_days,n_future=n_future,num_of_epoch = update_epoch_num)

  return predictions

print(df.shape[0])
pree = experiment(df[0:450],df[450:],5,bit_price)
print("finalllllll")
display(pree)
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 572
# finalllllll
#         date      real          pred
# 0 2022-07-01  19104.61  16815.767578
# 1 2022-07-02  19247.00  10590.602539
# 2 2022-07-03  19082.80   5440.163086
# 3 2022-07-04  20284.73   3735.459961
# 4 2022-07-05  19930.98   5037.987305
# 5 2022-07-06  20460.50  11650.584961
# 6 2022-07-29  23814.05  21577.966797

# %%
display(df)
df_testy = df.copy()
import numpy as np
def make_zeros(df_,name):
  df = df_.copy()
  df[name] = np.where(np.isnan(df[name]) == False, 0, df[name])
  return df

for i in df_testy['close']:
  print(i)
  print(type(i))
df_testy = df.copy()
cols = list(df)[2:6]
for col in cols:
  df_testy = make_zeros(df_testy,col)
print(cols)
display(df_testy)
pree2 = experiment(df_testy[0:450],df_testy[450:],5,bit_price)
display(pree2)
# Out:
#           date     close  Negative   Neutral  Positive   count
# 0   2021-02-05  39415.76  0.090510  0.468611  0.440879  1875.0
# 1   2021-02-06  38897.95  0.087718  0.457682  0.454601  2586.0
# 2   2021-02-07  38107.34  0.076292  0.513266  0.410442  2183.0
# 3   2021-02-08  46653.50  0.074992  0.408843  0.516166  5455.0
# 4   2021-02-09  46309.88  0.079048  0.440184  0.480768  3417.0
# ..         ...       ...       ...       ...       ...     ...
# 567 2022-08-26       NaN       NaN       NaN       NaN     NaN
# 568 2022-08-27       NaN       NaN       NaN       NaN     NaN
# 569 2022-08-28       NaN       NaN       NaN       NaN     NaN
# 570 2022-08-29       NaN       NaN       NaN       NaN     NaN
# 571 2022-08-30  20413.79  0.178000  0.447730  0.374270  8313.0
#
# [572 rows x 6 columns]
# 39415.76
# <class 'float'>
# 38897.95
# <class 'float'>
# 38107.34
# <class 'float'>
# 46653.5
# <class 'float'>
# 46309.88
# <class 'float'>
# 45513.94
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 47381.8
# <class 'float'>
# 47185.29
# <class 'float'>
# 49587.2
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 51241.23
# <class 'float'>
# 55761.1
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 51847.25
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 46408.05
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 57111.63
# <class 'float'>
# 56705.84
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 58638.14
# <class 'float'>
# 57934.16
# <class 'float'>
# 56559.59
# <class 'float'>
# 58014.19
# <class 'float'>
# 59160.0
# <class 'float'>
# 60240.83
# <class 'float'>
# 60325.66
# <class 'float'>
# 60415.91
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 55992.97
# <class 'float'>
# 57175.61
# <class 'float'>
# 54586.65
# <class 'float'>
# 55255.57
# <class 'float'>
# 53508.08
# <class 'float'>
# 50329.66
# <class 'float'>
# 50195.42
# <class 'float'>
# 49721.97
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 39572.33
# <class 'float'>
# 37672.47
# <class 'float'>
# 38271.59
# <class 'float'>
# 36503.31
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 32606.96
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 33540.48
# <class 'float'>
# 34670.0
# <class 'float'>
# 34360.84
# <class 'float'>
# 33942.22
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 31924.93
# <class 'float'>
# 31313.83
# <class 'float'>
# 32169.82
# <class 'float'>
# 31547.22
# <class 'float'>
# 29605.35
# <class 'float'>
# 29853.86
# <class 'float'>
# 31947.52
# <class 'float'>
# 32598.43
# <class 'float'>
# 33689.58
# <class 'float'>
# 34192.14
# <class 'float'>
# 38312.57
# <class 'float'>
# 36851.52
# <class 'float'>
# 39848.44
# <class 'float'>
# 39638.77
# <class 'float'>
# 39982.79
# <class 'float'>
# 41840.36
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 39440.62
# <class 'float'>
# 40250.79
# <class 'float'>
# 43720.0
# <class 'float'>
# 44391.34
# <class 'float'>
# 43529.34
# <class 'float'>
# 45727.39
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 46910.99
# <class 'float'>
# 47400.89
# <class 'float'>
# 46435.44
# <class 'float'>
# 45078.79
# <class 'float'>
# 44074.77
# <class 'float'>
# 47042.28
# <class 'float'>
# 48839.62
# <class 'float'>
# 48837.62
# <class 'float'>
# nan
# <class 'float'>
# 49350.0
# <class 'float'>
# 47995.78
# <class 'float'>
# 47931.0
# <class 'float'>
# 46845.94
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 45181.52
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 62600.0
# <class 'float'>
# 63870.2
# <class 'float'>
# 65077.99
# <class 'float'>
# 63243.4
# <class 'float'>
# 61234.9
# <class 'float'>
# 61226.0
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 58884.7
# <class 'float'>
# 61706.36
# <class 'float'>
# 61669.43
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 62249.6
# <class 'float'>
# 61172.03
# <class 'float'>
# 62199.69
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 64857.63
# <class 'float'>
# 63805.12
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 55911.16
# <class 'float'>
# 58596.83
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 57756.25
# <class 'float'>
# 57952.35
# <class 'float'>
# 54409.03
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 49333.66
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 46312.19
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 46502.44
# <class 'float'>
# 47207.99
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 42631.64
# <class 'float'>
# 43525.85
# <class 'float'>
# 42679.68
# <class 'float'>
# 42947.72
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 41954.5
# <class 'float'>
# 38462.49
# <class 'float'>
# 36341.4
# <class 'float'>
# 35080.27
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 43819.66
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 43599.82
# <class 'float'>
# 44014.68
# <class 'float'>
# 43619.61
# <class 'float'>
# 40725.83
# <class 'float'>
# 40164.68
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 43331.62
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 37885.04
# <class 'float'>
# 38685.62
# <class 'float'>
# 41230.39
# <class 'float'>
# 40790.0
# <class 'float'>
# 38724.13
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 38767.4
# <class 'float'>
# 39177.73
# <class 'float'>
# 41025.46
# <class 'float'>
# 40555.62
# <class 'float'>
# 41815.86
# <class 'float'>
# 41969.76
# <class 'float'>
# 40861.3
# <class 'float'>
# 42240.26
# <class 'float'>
# 42101.27
# <class 'float'>
# 42754.74
# <class 'float'>
# 43984.86
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 41339.6
# <class 'float'>
# 40199.81
# <class 'float'>
# 40437.47
# <class 'float'>
# 40253.71
# <class 'float'>
# 39837.45
# <class 'float'>
# 40709.48
# <class 'float'>
# 41406.0
# <class 'float'>
# 41711.06
# <class 'float'>
# 40503.04
# <class 'float'>
# 39482.0
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 39352.25
# <class 'float'>
# 39514.57
# <class 'float'>
# 38659.72
# <class 'float'>
# 38045.62
# <class 'float'>
# 38666.89
# <class 'float'>
# 38475.81
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 31202.34
# <class 'float'>
# 28257.39
# <class 'float'>
# 30485.68
# <class 'float'>
# 29525.0
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 30141.4
# <class 'float'>
# 29289.62
# <class 'float'>
# 30145.88
# <class 'float'>
# 29802.96
# <class 'float'>
# 29003.18
# <class 'float'>
# 28785.15
# <class 'float'>
# 28959.53
# <class 'float'>
# 30343.45
# <class 'float'>
# 31764.22
# <class 'float'>
# 31597.63
# <class 'float'>
# 29694.26
# <class 'float'>
# 30510.74
# <class 'float'>
# 29530.01
# <class 'float'>
# 29737.91
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 21166.08
# <class 'float'>
# 20710.45
# <class 'float'>
# 20267.28
# <class 'float'>
# 20050.72
# <class 'float'>
# 19713.14
# <class 'float'>
# 19104.61
# <class 'float'>
# 19247.0
# <class 'float'>
# 19082.8
# <class 'float'>
# 20284.73
# <class 'float'>
# 19930.98
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 21857.54
# <class 'float'>
# 21147.15
# <class 'float'>
# 21076.57
# <class 'float'>
# 23126.1
# <class 'float'>
# 23921.33
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# nan
# <class 'float'>
# 20413.79
# <class 'float'>
# ['Negative', 'Neutral', 'Positive', 'count']
#           date     close  Negative  Neutral  Positive  count
# 0   2021-02-05  39415.76       0.0      0.0       0.0    0.0
# 1   2021-02-06  38897.95       0.0      0.0       0.0    0.0
# 2   2021-02-07  38107.34       0.0      0.0       0.0    0.0
# 3   2021-02-08  46653.50       0.0      0.0       0.0    0.0
# 4   2021-02-09  46309.88       0.0      0.0       0.0    0.0
# ..         ...       ...       ...      ...       ...    ...
# 567 2022-08-26       NaN       NaN      NaN       NaN    NaN
# 568 2022-08-27       NaN       NaN      NaN       NaN    NaN
# 569 2022-08-28       NaN       NaN      NaN       NaN    NaN
# 570 2022-08-29       NaN       NaN      NaN       NaN    NaN
# 571 2022-08-30  20413.79       0.0      0.0       0.0    0.0
#
# [572 rows x 6 columns]
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#         date      real          pred
# 0 2022-07-01  19104.61   7220.866211
# 1 2022-07-02  19247.00   5173.518555
# 2 2022-07-03  19082.80   3833.249023
# 3 2022-07-04  20284.73   3312.530273
# 4 2022-07-05  19930.98   4503.202148
# 5 2022-07-06  20460.50   6608.334961
# 6 2022-07-29  23814.05  18716.996094

# %%
print(df.shape)
from sklearn.metrics import mean_squared_error as mse
import numpy as np
import tensorflow as tf
import random
from statistics import mean
from random import randint


def multi_exp(df,seed,past_days,update_epoch_num):
  df_uni = df.copy()
  cols = list(df)[2:6]
  for col in cols:
    df_uni = make_zeros(df_uni,col)

  df_c = df.copy()
  df_c = make_zeros(df_c,'count')

  #seed = 42
  np.random.seed(seed)
  tf.random.set_seed(seed)
  random.seed(seed)

  full = experiment(df[0:450],df[450:],past_days,bit_price,update_epoch_num=update_epoch_num)
  uni = experiment(df_uni[0:450],df_uni[450:],past_days,bit_price,update_epoch_num=update_epoch_num)
  no_c = experiment(df_c[0:450],df_c[450:],past_days,bit_price,update_epoch_num=update_epoch_num)
  #display(full)
  #display(no_c)
  #display(uni)

  full_mse = mse(full['real'],full['pred'])
  no_c_mse = mse(no_c['real'],no_c['pred'])
  uni_mse = mse(uni['real'],uni['pred'])
  out_df = pd.DataFrame() 
  out_df['date'] = full['date']
  out_df['real'] = full['real']
  out_df['full_pred'] = full['pred']
  out_df['no_count_pred'] = no_c['pred']
  out_df['univariate_close'] = uni['pred']
  #print(full_mse)
  #print(no_c_mse)
  #print(uni_mse)
  return out_df,full_mse,no_c_mse,uni_mse


#seeds = [14,843,8114,18832,124128,21,557,98664,31,64356,74,72755,3451573,1345]
def multi_runs(df,save_folder,past_days,update_epoch_num,repeat_num = 50,):
  save_folder
  seeds =[]
  for i in range(repeat_num):
    value = randint(0, 10000)
    seeds.append(value)
  full = []
  no_c = []
  uni = []
  df_out_ls = []
  for i in tqdm(seeds):
    out_df,f,c,u  = multi_exp(df,i,past_days=past_days,update_epoch_num=update_epoch_num )
    full.append(f)
    no_c.append(c)
    uni.append(u)
    df_out_ls.append(out_df)
  for idx,df in enumerate(df_out_ls):
    save = save_folder + "/lstm_res_" + str(idx) + ".csv"
  print("final values")
  print(mean(full))
  print(mean(no_c))
  print(mean(uni))

  return mean(full),mean(no_c),mean(uni)

def multi_update_epoch(df,range = 5,repeat_num = 20):
  str_ls = []
  for i in range(range):
    f,c,u = multi_runs(df,save_folder = "dasd",past_days = 5,update_epoch_num=i,repeat_num = repeat_num)
    print("num of epoch: ",i," full: ",f," no count: ",c," uni: ",u)
    str_ = "num of epoch: " + str(i) + " full: " + str(f) +" no count: "+str(c)+" uni: "+str(u)
    str_ls.append(str_)

  for i in str_ls:
    print(i)
  return(str_ls)
#str_ls = multi_update_epoch(df)
# Out:
# (572, 6)

# %%
df_num_epoch = pd.DataFrame()
#df_num_epoch['Number of update epochs'] = [0,1,2,3,4]
df_num_epoch['Full Multivariate'] = [99567092,570093196,2591051196,7345883285,9543707618]
df_num_epoch['Full Multivariate with no count'] = [40715909,16649711,19036986,677102341,1523559195]
df_num_epoch['Univariate'] = [117228135,86411366,85712882,88751002,82655715]

display(df_num_epoch)
# Out:
#    Full Multivariate  Full Multivariate with no count  Univariate
# 0           99567092                         40715909   117228135
# 1          570093196                         16649711    86411366
# 2         2591051196                         19036986    85712882
# 3         7345883285                        677102341    88751002
# 4         9543707618                       1523559195    82655715

# %%
def multi_day(df_,repeat_num = 50,update_epoch_num=1):
  df = pd.DataFrame(columns = ['Number of Past Days', 'Full Multivariate', 'Full Multivariate with no count','Univariate'])

  for i in range(5,9):
    print("doing ",i," past days")
    f,c,u = multi_runs(df_,save_folder = "dasd",past_days = i,update_epoch_num=update_epoch_num,repeat_num = repeat_num)
    new_row = {'Number of Past Days':i, 'Full Multivariate':int(f),'Full Multivariate with no count':int(c),'Univariate':int(u)}
    print("got it ")
    print(f)
    df = df.append(new_row,ignore_index=True)
    df.to_csv("/content/drive/MyDrive/fyp/fyp2/final models and datasets/lstm/final_res_multidayV2_3.csv")
  return df

display(df)
df_multi_day = multi_day(df,repeat_num =100)
display(df_multi_day)
# Out:
#           date     close  Negative   Neutral  Positive   count
# 0   2021-02-05  39415.76  0.090510  0.468611  0.440879  1875.0
# 1   2021-02-06  38897.95  0.087718  0.457682  0.454601  2586.0
# 2   2021-02-07  38107.34  0.076292  0.513266  0.410442  2183.0
# 3   2021-02-08  46653.50  0.074992  0.408843  0.516166  5455.0
# 4   2021-02-09  46309.88  0.079048  0.440184  0.480768  3417.0
# ..         ...       ...       ...       ...       ...     ...
# 567 2022-08-26       NaN       NaN       NaN       NaN     NaN
# 568 2022-08-27       NaN       NaN       NaN       NaN     NaN
# 569 2022-08-28       NaN       NaN       NaN       NaN     NaN
# 570 2022-08-29       NaN       NaN       NaN       NaN     NaN
# 571 2022-08-30  20413.79  0.178000  0.447730  0.374270  8313.0
#
# [572 rows x 6 columns]
# doing  5  past days
#   0%|          | 0/100 [00:00<?, ?it/s]WARNING:tensorflow:Layer lstm_636 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_637 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_638 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_639 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_640 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_641 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   1%|          | 1/100 [00:33<54:27, 33.00s/it]WARNING:tensorflow:Layer lstm_642 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_643 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_644 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_645 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_646 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_647 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   2%|▏         | 2/100 [01:05<53:01, 32.46s/it]WARNING:tensorflow:Layer lstm_648 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_649 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_650 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_651 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_652 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_653 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   3%|▎         | 3/100 [01:36<51:59, 32.16s/it]WARNING:tensorflow:Layer lstm_654 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_655 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_656 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_657 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_658 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_659 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   4%|▍         | 4/100 [02:08<51:19, 32.07s/it]WARNING:tensorflow:Layer lstm_660 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_661 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_662 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_663 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_664 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_665 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   5%|▌         | 5/100 [02:40<50:45, 32.06s/it]WARNING:tensorflow:Layer lstm_666 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_667 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_668 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_669 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_670 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_671 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   6%|▌         | 6/100 [03:12<50:07, 31.99s/it]WARNING:tensorflow:Layer lstm_672 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_673 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_674 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_675 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_676 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_677 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   7%|▋         | 7/100 [03:44<49:33, 31.97s/it]WARNING:tensorflow:Layer lstm_678 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_679 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_680 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_681 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_682 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_683 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   8%|▊         | 8/100 [04:16<49:01, 31.98s/it]WARNING:tensorflow:Layer lstm_684 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_685 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_686 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_687 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_688 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_689 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#   9%|▉         | 9/100 [04:48<48:34, 32.02s/it]WARNING:tensorflow:Layer lstm_690 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_691 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_692 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_693 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_694 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_695 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  10%|█         | 10/100 [05:21<48:10, 32.11s/it]WARNING:tensorflow:Layer lstm_696 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_697 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_698 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_699 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_700 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_701 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  11%|█         | 11/100 [05:53<47:34, 32.07s/it]WARNING:tensorflow:Layer lstm_702 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_703 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_704 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_705 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_706 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_707 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  12%|█▏        | 12/100 [06:25<47:02, 32.08s/it]WARNING:tensorflow:Layer lstm_708 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_709 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_710 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_711 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_712 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_713 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  13%|█▎        | 13/100 [06:57<46:32, 32.10s/it]WARNING:tensorflow:Layer lstm_714 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_715 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_716 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_717 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_718 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_719 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  14%|█▍        | 14/100 [07:29<45:59, 32.08s/it]WARNING:tensorflow:Layer lstm_720 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_721 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_722 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_723 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_724 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_725 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  15%|█▌        | 15/100 [08:01<45:24, 32.05s/it]WARNING:tensorflow:Layer lstm_726 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_727 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_728 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_729 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_730 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_731 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  16%|█▌        | 16/100 [08:33<44:49, 32.02s/it]WARNING:tensorflow:Layer lstm_732 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_733 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_734 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_735 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_736 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_737 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  17%|█▋        | 17/100 [09:05<44:17, 32.02s/it]WARNING:tensorflow:Layer lstm_738 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_739 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_740 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_741 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_742 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_743 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  18%|█▊        | 18/100 [09:37<43:49, 32.07s/it]WARNING:tensorflow:Layer lstm_744 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_745 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_746 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_747 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_748 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_749 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  19%|█▉        | 19/100 [10:09<43:15, 32.04s/it]WARNING:tensorflow:Layer lstm_750 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_751 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_752 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_753 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_754 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_755 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  20%|██        | 20/100 [10:41<42:50, 32.14s/it]WARNING:tensorflow:Layer lstm_756 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_757 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_758 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_759 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_760 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_761 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  21%|██        | 21/100 [11:13<42:17, 32.12s/it]WARNING:tensorflow:Layer lstm_762 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_763 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_764 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_765 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_766 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_767 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  22%|██▏       | 22/100 [11:46<41:46, 32.14s/it]WARNING:tensorflow:Layer lstm_768 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_769 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_770 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_771 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_772 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_773 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  23%|██▎       | 23/100 [12:18<41:17, 32.17s/it]WARNING:tensorflow:Layer lstm_774 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_775 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_776 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_777 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_778 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_779 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  24%|██▍       | 24/100 [12:50<40:38, 32.08s/it]WARNING:tensorflow:Layer lstm_780 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_781 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_782 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_783 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_784 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_785 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  25%|██▌       | 25/100 [13:22<40:11, 32.16s/it]WARNING:tensorflow:Layer lstm_786 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_787 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_788 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_789 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_790 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_791 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  26%|██▌       | 26/100 [13:54<39:37, 32.12s/it]WARNING:tensorflow:Layer lstm_792 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_793 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_794 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_795 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_796 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_797 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  27%|██▋       | 27/100 [14:26<39:04, 32.12s/it]WARNING:tensorflow:Layer lstm_798 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_799 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_800 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_801 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_802 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_803 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  28%|██▊       | 28/100 [14:58<38:31, 32.11s/it]WARNING:tensorflow:Layer lstm_804 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_805 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_806 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_807 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_808 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_809 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  29%|██▉       | 29/100 [15:30<38:01, 32.13s/it]WARNING:tensorflow:Layer lstm_810 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_811 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_812 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_813 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_814 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_815 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  30%|███       | 30/100 [16:03<37:31, 32.17s/it]WARNING:tensorflow:Layer lstm_816 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_817 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_818 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_819 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_820 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_821 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  31%|███       | 31/100 [16:35<36:57, 32.14s/it]WARNING:tensorflow:Layer lstm_822 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_823 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_824 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_825 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_826 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_827 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  32%|███▏      | 32/100 [17:07<36:24, 32.12s/it]WARNING:tensorflow:Layer lstm_828 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_829 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_830 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_831 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_832 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_833 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  33%|███▎      | 33/100 [17:39<35:56, 32.19s/it]WARNING:tensorflow:Layer lstm_834 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_835 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_836 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_837 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_838 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_839 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  34%|███▍      | 34/100 [18:11<35:25, 32.20s/it]WARNING:tensorflow:Layer lstm_840 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_841 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_842 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_843 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_844 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_845 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  35%|███▌      | 35/100 [18:44<34:54, 32.22s/it]WARNING:tensorflow:Layer lstm_846 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_847 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_848 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_849 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_850 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_851 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  36%|███▌      | 36/100 [19:16<34:23, 32.24s/it]WARNING:tensorflow:Layer lstm_852 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_853 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_854 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_855 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_856 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_857 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  37%|███▋      | 37/100 [19:48<33:50, 32.23s/it]WARNING:tensorflow:Layer lstm_858 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_859 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_860 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_861 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_862 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_863 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  38%|███▊      | 38/100 [20:20<33:16, 32.20s/it]WARNING:tensorflow:Layer lstm_864 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_865 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_866 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_867 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_868 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_869 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  39%|███▉      | 39/100 [20:53<32:47, 32.25s/it]WARNING:tensorflow:Layer lstm_870 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_871 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_872 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_873 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_874 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_875 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  40%|████      | 40/100 [21:25<32:13, 32.22s/it]WARNING:tensorflow:Layer lstm_876 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_877 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_878 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_879 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_880 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_881 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  41%|████      | 41/100 [21:57<31:45, 32.30s/it]WARNING:tensorflow:Layer lstm_882 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_883 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_884 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_885 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_886 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_887 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  42%|████▏     | 42/100 [22:30<31:12, 32.28s/it]WARNING:tensorflow:Layer lstm_888 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_889 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_890 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_891 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_892 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_893 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  43%|████▎     | 43/100 [23:02<30:38, 32.26s/it]WARNING:tensorflow:Layer lstm_894 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_895 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_896 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_897 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_898 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_899 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  44%|████▍     | 44/100 [23:34<30:01, 32.17s/it]WARNING:tensorflow:Layer lstm_900 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_901 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_902 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_903 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_904 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_905 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  45%|████▌     | 45/100 [24:06<29:28, 32.15s/it]WARNING:tensorflow:Layer lstm_906 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_907 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_908 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_909 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_910 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_911 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# ...
# WARNING:tensorflow:Layer lstm_2947 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2948 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2949 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2950 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2951 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  86%|████████▌ | 86/100 [40:39<06:45, 28.95s/it]WARNING:tensorflow:Layer lstm_2952 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2953 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2954 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2955 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2956 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2957 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  87%|████████▋ | 87/100 [41:08<06:18, 29.14s/it]WARNING:tensorflow:Layer lstm_2958 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2959 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2960 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2961 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2962 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2963 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  88%|████████▊ | 88/100 [41:37<05:46, 28.87s/it]WARNING:tensorflow:Layer lstm_2964 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2965 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2966 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2967 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2968 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2969 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  89%|████████▉ | 89/100 [42:05<05:16, 28.81s/it]WARNING:tensorflow:Layer lstm_2970 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2971 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2972 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2973 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2974 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2975 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  90%|█████████ | 90/100 [42:34<04:47, 28.76s/it]WARNING:tensorflow:Layer lstm_2976 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2977 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2978 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2979 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2980 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2981 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  91%|█████████ | 91/100 [43:02<04:17, 28.59s/it]WARNING:tensorflow:Layer lstm_2982 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2983 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2984 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2985 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2986 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2987 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  92%|█████████▏| 92/100 [43:31<03:49, 28.64s/it]WARNING:tensorflow:Layer lstm_2988 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2989 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2990 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2991 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2992 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2993 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  93%|█████████▎| 93/100 [44:00<03:20, 28.66s/it]WARNING:tensorflow:Layer lstm_2994 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2995 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2996 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2997 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2998 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2999 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  94%|█████████▍| 94/100 [44:28<02:50, 28.45s/it]WARNING:tensorflow:Layer lstm_3000 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3001 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3002 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3003 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3004 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3005 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  95%|█████████▌| 95/100 [44:56<02:22, 28.48s/it]WARNING:tensorflow:Layer lstm_3006 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3007 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3008 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3009 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3010 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3011 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  96%|█████████▌| 96/100 [45:24<01:53, 28.32s/it]WARNING:tensorflow:Layer lstm_3012 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3013 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3014 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3015 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3016 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3017 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  97%|█████████▋| 97/100 [45:53<01:25, 28.54s/it]WARNING:tensorflow:Layer lstm_3018 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3019 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3020 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3021 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3022 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3023 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  98%|█████████▊| 98/100 [46:22<00:57, 28.73s/it]WARNING:tensorflow:Layer lstm_3024 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3025 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3026 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3027 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3028 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3029 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
#  99%|█████████▉| 99/100 [46:52<00:28, 28.89s/it]WARNING:tensorflow:Layer lstm_3030 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3031 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3032 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3033 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3034 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3035 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 100%|██████████| 100/100 [47:21<00:00, 28.42s/it]
# final values
# 337115583.84706897
# 344808569.9912686
# 230425822.92015785
# got it
# 337115583.84706897
#   Number of Past Days Full Multivariate Full Multivariate with no count  \
# 0                   5         400355416                       478386117
# 1                   6         131947502                       238444605
# 2                   7         518740823                      3652583697
# 3                   8         337115583                       344808569
#
#   Univariate
# 0  166742560
# 1   11642315
# 2   17922777
# 3  230425822

# %%
#df.to_csv("/content/drive/MyDrive/fyp/fyp2/final_lstm_df.csv")

# %%
print(mse(pree1['real'],pree1['pred']))
print(mse(pree2['real'],pree2['pred']))
print(mse(pree3['real'],pree3['pred']))


plt.plot(pree1['date'],pree1['real'],label = "real")
plt.plot(pree1['date'],pree1['pred'],label = "pred multi")
plt.plot(pree2['date'],pree2['pred'],label = "pred uni")
plt.plot(pree3['date'],pree3['pred'],label = "multi no count pred")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1e5ee79dc461> in <module>
# ----> 1 print(mse(pree1['real'],pree1['pred']))
#       2 print(mse(pree2['real'],pree2['pred']))
#       3 print(mse(pree3['real'],pree3['pred']))
#       4
#       5
#
# NameError: name 'pree1' is not defined

# %%
print(type(df))

# %%
#Predicting...
#Libraries that will help us extract only business days in the US.
#Otherwise our dates would be wrong when we look back (or forward).  
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
us_bd = CustomBusinessDay(calendar=USFederalHolidayCalendar())
#Remember that we can only predict one day in future as our model needs 5 variables
#as inputs for prediction. We only have all 5 variables until the last day in our dataset.
n_past = 16
n_days_for_prediction=15  #let us predict past 15 days

predict_period_dates = pd.date_range(list(train_dates)[-n_past], periods=n_days_for_prediction, freq=us_bd).tolist()
print(predict_period_dates)

#Make prediction
prediction = model.predict(trainX[-n_days_for_prediction:]) #shape = (n, 1) where n is the n_days_for_prediction

#Perform inverse transformation to rescale back to original range
#Since we used 5 variables for transform, the inverse expects same dimensions
#Therefore, let us copy our values 5 times and discard them after inverse transform
prediction_copies = np.repeat(prediction, df_for_training.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]


# Convert timestamp to date
forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i.date())
    
df_forecast = pd.DataFrame({'date':np.array(forecast_dates), 'close':y_pred_future})
df_forecast['date']=pd.to_datetime(df_forecast['date'])


original = df[['date', 'close']]
original['date']=pd.to_datetime(original['date'])
original = original.loc[original['date'] >= '2020-5-1']

sns.lineplot(original['date'], original['close'])
sns.lineplot(df_forecast['date'], df_forecast['close'])
