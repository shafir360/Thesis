# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers
# !pip install datasets
# !pip install sentencepiece
# !pip install GPUtil
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
#!pip install wandb
import json
from transformers import AutoTokenizer
from transformers import TFAutoModelForSequenceClassification
import tensorflow as tf
from tensorflow.keras.losses import SparseCategoricalCrossentropy

import numpy as np
import pandas as pd




import pyarrow as pa
import pyarrow.dataset as ds
import pandas as pd
from datasets import Dataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.1-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 3.8 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 10.6 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 24.2 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 46.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 tokenizers-0.12.1 transformers-4.21.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      |████████████████████████████████| 365 kB 3.9 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.12.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Collecting fsspec[http]>=2021.11.1
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      |████████████████████████████████| 141 kB 64.9 MB/s
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.8.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 63.6 MB/s
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 68.3 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 59.7 MB/s
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, fsspec, xxhash, responses, multiprocess, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.4.0 fsspec-2022.7.1 multiprocess-0.70.13 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 4.0 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting GPUtil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
# Building wheels for collected packages: GPUtil
#   Building wheel for GPUtil (setup.py) ... done
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7411 sha256=201613b280698645aec0e02f970376386e5fad0d1e02a953f37240e1bfd635c9
#   Stored in directory: /root/.cache/pip/wheels/6e/f8/83/534c52482d6da64622ddbf72cd93c35d2ef2881b78fd08ff0c
# Successfully built GPUtil
# Installing collected packages: GPUtil
# Successfully installed GPUtil-1.4.0

# %%
def ConvertLabel2ModelLabel(label):
  if label == 'Positive':
    o = 2
  elif label == 'Neutral':
    o = 1
  elif label == 'Negative':
    o = 0
  elif label == 'spam':
    o = 1
  else: 
    print(" error at ConvertLabel2ModelLabel label is " , label)
    o = np.nan
  return o

import torch
from GPUtil import showUtilization as gpu_usage
from numba import cuda

def free_gpu_cache():
    print("Initial GPU Usage")
    gpu_usage()                             

    torch.cuda.empty_cache()

    cuda.select_device(0)
    cuda.close()
    cuda.select_device(0)

    print("GPU Usage after emptying the cache")
    gpu_usage()

# %%
train_path = '/content/drive/MyDrive/fyp/fyp2/final models and datasets/dataset/dataset_new_with_self_label_3.0:4.0:4.0/train_dataset.csv'
valid_path = '/content/drive/MyDrive/fyp/fyp2/final models and datasets/dataset/dataset_new_with_self_label_3.0:4.0:4.0/valid_dataset.csv'
#model_name = "Tomas23/twitter-roberta-base-mar2022-finetuned-sentiment"
#out_dir = '/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/tomas23_3:4:4/with_high'
#out_dir2 = '/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/tomas23_3:4:4/with_high_then_low'

import shutil





name_of_text_column = "text"
hyperparameter_tuning = False
reduce_ = False
num_hyper_trails = 100
epoch = 60

df_train = pd.read_csv(train_path)

df_train_high = df_train[df_train['quality']=="high"]
df_train_low = df_train[df_train['quality']=="low"]

df_valid = pd.read_csv(valid_path)

display(df_train)
display(df_valid)
display(df_train_high)
display(df_train_low)
# Out:
#       Unnamed: 0                                               text     label  \
# 0            339  КриптоВести BTC 🤘  Blockasset Taps Well-Known ...  Positive
# 1            747  Full thanks to  as they have analysed this Bit...   Neutral
# 2            301  __crypto _tw  🔥 SanjiInu 🔥  💥 KYC, CHARITY, NF...   Neutral
# 3           1743  $btc btc health check! No custom death cross; ...   Neutral
# 4           1108  44 🏦FTX | BTC PERP  🦋 If you have trouble imag...   Neutral
# ...          ...                                                ...       ...
# 2785         683  This will be very useful in the future because...  Positive
# 2786        1451  And without Bitcoin Maxies hyping Bitcoin , th...  Positive
# 2787        1106  11 IST   88.724  37996.605 ₿  3371120.946  253...  Positive
# 2788        1787                     Bitcoin is Liberation Network.  Positive
# 2789         344  bitcoin is the best MONEY in the history of ma...   Neutral
#
#              source quality
# 0      new_turk_low     low
# 1     new_turk_high    high
# 2       self_manual    high
# 3      new_turk_low     low
# 4      new_turk_low     low
# ...             ...     ...
# 2785   new_turk_low     low
# 2786   new_turk_low     low
# 2787   new_turk_low     low
# 2788   new_turk_low     low
# 2789   new_turk_low     low
#
# [2790 rows x 5 columns]
#       Unnamed: 0                                               text     label  \
# 0             71  Full thanks to  as they have analysed this Bit...  Positive
# 1            266             Typing mistake for Satoshi not bitcoin   Neutral
# 2            410  Saitama SaitamaWolfPack SaitamaInu SaitaMask $...   Neutral
# 3            333  100%, the nuclear industry has no idea what is...   Neutral
# 4            401  airdrop Airdrops Crypto BSC DeFi Polygon Bitco...   Neutral
# ...          ...                                                ...       ...
# 1190         171  This is a very good project so don't miss to j...  Positive
# 1191         319        Whoever didn’t panic sell we made it 🤝🎉 BTC  Positive
# 1192         896  To know more about IPOs and Unlisted shares, c...   Neutral
# 1193         425  Soon to the moon 🌜   Unitycol $Unity Unityprot...  Positive
# 1194         153  Bitcoin Price     $48665.02     $37554.85     ...   Neutral
#
#                 source quality
# 0     incomplete_valid    high
# 1     incomplete_valid    high
# 2     incomplete_valid    high
# 3        new_turk_high    high
# 4          self_manual    high
# ...                ...     ...
# 1190     new_turk_high    high
# 1191     new_turk_high    high
# 1192     new_turk_high    high
# 1193  incomplete_valid    high
# 1194     new_turk_high    high
#
# [1195 rows x 5 columns]
#       Unnamed: 0                                               text     label  \
# 1            747  Full thanks to  as they have analysed this Bit...   Neutral
# 2            301  __crypto _tw  🔥 SanjiInu 🔥  💥 KYC, CHARITY, NF...   Neutral
# 6            758  Full thanks to  as they have analysed this Bit...   Neutral
# 15           285  BTC DOMINANCE  BULLISH PENNANT READY FOR BREAKOUT  Positive
# 25           530  Mining Farm Turning Waste Coal Into Bitcoin Ra...  Positive
# ...          ...                                                ...       ...
# 2762          11  Bitcoin interoperability platform Interlay rai...  Positive
# 2772         426  🇧🇷 BRL - R$ 0.00238059 🇺🇸 USD - $ 0.00042746 🇪...   Neutral
# 2775         652         Current Bitcoin Price is $40714 BTC Crypto   Neutral
# 2780         140  btc Crypto  cryptocurrency   Target 1 close.  ...  Positive
# 2783         330  CBNEWS WEEKLY CRYPTO WRAPUP!!!  ZILLIQA AIR DR...   Neutral
#
#              source quality
# 1     new_turk_high    high
# 2       self_manual    high
# 6     new_turk_high    high
# 15           manual    high
# 25    new_turk_high    high
# ...             ...     ...
# 2762  new_turk_high    high
# 2772    self_manual    high
# 2775  new_turk_high    high
# 2780  new_turk_high    high
# 2783    self_manual    high
#
# [539 rows x 5 columns]
#       Unnamed: 0                                               text     label  \
# 0            339  КриптоВести BTC 🤘  Blockasset Taps Well-Known ...  Positive
# 3           1743  $btc btc health check! No custom death cross; ...   Neutral
# 4           1108  44 🏦FTX | BTC PERP  🦋 If you have trouble imag...   Neutral
# 5            103             Bitcoin maxis are born in bear markets  Positive
# 7           1768  BTC has risen by 9.19% in the last week. The p...   Neutral
# ...          ...                                                ...       ...
# 2785         683  This will be very useful in the future because...  Positive
# 2786        1451  And without Bitcoin Maxies hyping Bitcoin , th...  Positive
# 2787        1106  11 IST   88.724  37996.605 ₿  3371120.946  253...  Positive
# 2788        1787                     Bitcoin is Liberation Network.  Positive
# 2789         344  bitcoin is the best MONEY in the history of ma...   Neutral
#
#             source quality
# 0     new_turk_low     low
# 3     new_turk_low     low
# 4     new_turk_low     low
# 5     new_turk_low     low
# 7     new_turk_low     low
# ...            ...     ...
# 2785  new_turk_low     low
# 2786  new_turk_low     low
# 2787  new_turk_low     low
# 2788  new_turk_low     low
# 2789  new_turk_low     low
#
# [2251 rows x 5 columns]

# %%
df_train['label'] = df_train['label'].apply(ConvertLabel2ModelLabel)
df_valid['label'] = df_valid['label'].apply(ConvertLabel2ModelLabel)

df_train_high['label'] = df_train_high['label'].apply(ConvertLabel2ModelLabel)
df_train_low['label'] = df_train_low['label'].apply(ConvertLabel2ModelLabel)

display(df_train)
display(df_valid)
display(df_train_high)
display(df_train_low)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#       Unnamed: 0                                               text  label  \
# 0            339  КриптоВести BTC 🤘  Blockasset Taps Well-Known ...      2
# 1            747  Full thanks to  as they have analysed this Bit...      1
# 2            301  __crypto _tw  🔥 SanjiInu 🔥  💥 KYC, CHARITY, NF...      1
# 3           1743  $btc btc health check! No custom death cross; ...      1
# 4           1108  44 🏦FTX | BTC PERP  🦋 If you have trouble imag...      1
# ...          ...                                                ...    ...
# 2785         683  This will be very useful in the future because...      2
# 2786        1451  And without Bitcoin Maxies hyping Bitcoin , th...      2
# 2787        1106  11 IST   88.724  37996.605 ₿  3371120.946  253...      2
# 2788        1787                     Bitcoin is Liberation Network.      2
# 2789         344  bitcoin is the best MONEY in the history of ma...      1
#
#              source quality
# 0      new_turk_low     low
# 1     new_turk_high    high
# 2       self_manual    high
# 3      new_turk_low     low
# 4      new_turk_low     low
# ...             ...     ...
# 2785   new_turk_low     low
# 2786   new_turk_low     low
# 2787   new_turk_low     low
# 2788   new_turk_low     low
# 2789   new_turk_low     low
#
# [2790 rows x 5 columns]
#       Unnamed: 0                                               text  label  \
# 0             71  Full thanks to  as they have analysed this Bit...      2
# 1            266             Typing mistake for Satoshi not bitcoin      1
# 2            410  Saitama SaitamaWolfPack SaitamaInu SaitaMask $...      1
# 3            333  100%, the nuclear industry has no idea what is...      1
# 4            401  airdrop Airdrops Crypto BSC DeFi Polygon Bitco...      1
# ...          ...                                                ...    ...
# 1190         171  This is a very good project so don't miss to j...      2
# 1191         319        Whoever didn’t panic sell we made it 🤝🎉 BTC      2
# 1192         896  To know more about IPOs and Unlisted shares, c...      1
# 1193         425  Soon to the moon 🌜   Unitycol $Unity Unityprot...      2
# 1194         153  Bitcoin Price     $48665.02     $37554.85     ...      1
#
#                 source quality
# 0     incomplete_valid    high
# 1     incomplete_valid    high
# 2     incomplete_valid    high
# 3        new_turk_high    high
# 4          self_manual    high
# ...                ...     ...
# 1190     new_turk_high    high
# 1191     new_turk_high    high
# 1192     new_turk_high    high
# 1193  incomplete_valid    high
# 1194     new_turk_high    high
#
# [1195 rows x 5 columns]
#       Unnamed: 0                                               text  label  \
# 1            747  Full thanks to  as they have analysed this Bit...      1
# 2            301  __crypto _tw  🔥 SanjiInu 🔥  💥 KYC, CHARITY, NF...      1
# 6            758  Full thanks to  as they have analysed this Bit...      1
# 15           285  BTC DOMINANCE  BULLISH PENNANT READY FOR BREAKOUT      2
# 25           530  Mining Farm Turning Waste Coal Into Bitcoin Ra...      2
# ...          ...                                                ...    ...
# 2762          11  Bitcoin interoperability platform Interlay rai...      2
# 2772         426  🇧🇷 BRL - R$ 0.00238059 🇺🇸 USD - $ 0.00042746 🇪...      1
# 2775         652         Current Bitcoin Price is $40714 BTC Crypto      1
# 2780         140  btc Crypto  cryptocurrency   Target 1 close.  ...      2
# 2783         330  CBNEWS WEEKLY CRYPTO WRAPUP!!!  ZILLIQA AIR DR...      1
#
#              source quality
# 1     new_turk_high    high
# 2       self_manual    high
# 6     new_turk_high    high
# 15           manual    high
# 25    new_turk_high    high
# ...             ...     ...
# 2762  new_turk_high    high
# 2772    self_manual    high
# 2775  new_turk_high    high
# 2780  new_turk_high    high
# 2783    self_manual    high
#
# [539 rows x 5 columns]
#       Unnamed: 0                                               text  label  \
# 0            339  КриптоВести BTC 🤘  Blockasset Taps Well-Known ...      2
# 3           1743  $btc btc health check! No custom death cross; ...      1
# 4           1108  44 🏦FTX | BTC PERP  🦋 If you have trouble imag...      1
# 5            103             Bitcoin maxis are born in bear markets      2
# 7           1768  BTC has risen by 9.19% in the last week. The p...      1
# ...          ...                                                ...    ...
# 2785         683  This will be very useful in the future because...      2
# 2786        1451  And without Bitcoin Maxies hyping Bitcoin , th...      2
# 2787        1106  11 IST   88.724  37996.605 ₿  3371120.946  253...      2
# 2788        1787                     Bitcoin is Liberation Network.      2
# 2789         344  bitcoin is the best MONEY in the history of ma...      1
#
#             source quality
# 0     new_turk_low     low
# 3     new_turk_low     low
# 4     new_turk_low     low
# 5     new_turk_low     low
# 7     new_turk_low     low
# ...            ...     ...
# 2785  new_turk_low     low
# 2786  new_turk_low     low
# 2787  new_turk_low     low
# 2788  new_turk_low     low
# 2789  new_turk_low     low
#
# [2251 rows x 5 columns]

# %%
from transformers import Trainer
from transformers import TrainingArguments
#learning_rate = 5e-05
#batch_size = 16
#eval_batch_size = 4
seed = 40
#optimizer = Adam 
#with betas=(0.9,0.999) and epsilon=1e-08
adam_beta1 = 0.9
adam_beta2 =0.999
lr_scheduler_type = "linear"
num_epochs = 15
#args = TrainingArguments("test_trainer",report_to="wandb" ,logging_strategy = "epoch",evaluation_strategy="epoch",learning_rate = learning_rate,num_train_epochs = num_epochs,lr_scheduler_type =lr_scheduler_type, adam_beta1 = adam_beta1,adam_beta2 =adam_beta2  )


def run_trainer(model_name,out_dir,epoch,batch_size,df_train,df_valid,):
  df_train = df_train[['text','label']].set_index('text')
  df_valid = df_valid[['text','label']].set_index('text')
  #display(df_train)
  #display(df_valid)

  dataset = ds.dataset(pa.Table.from_pandas(df_valid).to_batches())
  ### convert to Huggingface dataset
  validation_dataset_torch = Dataset(pa.Table.from_pandas(df_valid))

  dataset = ds.dataset(pa.Table.from_pandas(df_train).to_batches())
  ### convert to Huggingface dataset
  training_dataset_torch = Dataset(pa.Table.from_pandas(df_train))

  #print(training_dataset_torch)
  #print(validation_dataset_torch)

  from transformers import AutoTokenizer

  tokenizer = AutoTokenizer.from_pretrained(model_name,model_max_length=512)



  def tokenize_function(data):
      return tokenizer(data['text'], padding="max_length", truncation=True,)


  train_dataset = training_dataset_torch.map(tokenize_function, batched=True)
  eval_dataset = validation_dataset_torch.map(tokenize_function, batched=True)
  print(train_dataset)
  print(eval_dataset)

  import numpy as np
  from datasets import load_metric

  metric = load_metric("matthews_correlation")

  def compute_metrics(eval_pred):
      logits, labels = eval_pred
      predictions = np.argmax(logits, axis=-1)
      return metric.compute(predictions=predictions, references=labels)


  from transformers import AutoModelForSequenceClassification

  model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=3)
  #model.to(device)
  args = TrainingArguments(
      #'/content/drive/MyDrive/fyp/fyp2/model/model2-supervised/' + f"{model_name}-finetuned-",
      #'/content/' + f"{model_name}-finetuned-",
      out_dir,
      #report_to="wandb",
      overwrite_output_dir = True,
      logging_dir = out_dir,
      evaluation_strategy = "epoch",
      logging_strategy = "epoch",
      #save_strategy = "NO",
      learning_rate=2.6510704963161386e-06,
      per_device_train_batch_size=batch_size,
      per_device_eval_batch_size=batch_size,
      num_train_epochs=epoch,
      weight_decay=0.01,
      metric_for_best_model='matthews_correlation',
      save_total_limit = 2,
      save_strategy = "epoch",
      load_best_model_at_end = True,
      seed = 18
      #push_to_hub=True,
  )



  trainer = Trainer(
      model,
      args,
      train_dataset=train_dataset,
      eval_dataset=eval_dataset,
      tokenizer=tokenizer,
      compute_metrics=compute_metrics
  )

  #trainer = Trainer(
    # model=model,
      #args=args,
    # train_dataset=train_dataset,
    #  eval_dataset=eval_dataset,
  #   compute_metrics=compute_metrics,
  #)


    # training
  train_result = trainer.train() 
  logs = trainer.state.log_history
  # compute train results
  metrics = train_result.metrics
  max_train_samples = len(train_dataset)
  metrics["train_samples"] = min(max_train_samples, len(train_dataset))

  # save train results
  trainer.log_metrics("train", metrics)
  trainer.save_metrics("train", metrics)

  # compute evaluation results
  metrics = trainer.evaluate()
  max_val_samples = len(eval_dataset)
  metrics["eval_samples"] = min(max_val_samples, len(eval_dataset))

  # save evaluation results
  trainer.log_metrics("eval", metrics)
  trainer.save_metrics("eval", metrics)
  import pickle
  save_logs_dir = out_dir
  name_logs = "logs"
  
  my_file = save_logs_dir + "/" + name_logs + ".p"
  print("saving to ",my_file )

  pickle.dump( logs, open( my_file, "wb" )    ) 

  ld = pickle.load( open( my_file, "rb" ) )


  print(logs)
  print(logs[2])
  print(type(logs))

  print(ld)
  print(type(ld))
  print(logs == ld)
  
  import torch
  torch.cuda.is_available() 
  from numba import cuda
  del trainer,args
  torch.cuda.empty_cache()
  #trainer.evaluate()

# %%
def run_both_training(model_name,out_dir="/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models",batch_size = 16,df_valid = df_valid):
  print("starting " ,model_name)
  out = out_dir + "/" + model_name + "/high"
 
  if not os.path.exists(out):
    
    # Create a new directory because it does not exist 
    os.makedirs(out)
  else:
    shutil.rmtree(out)

  run_trainer(model_name=model_name,out_dir = out,epoch =40,df_train = df_train_high,df_valid=df_valid,batch_size=batch_size)
  torch.cuda.empty_cache()
  print(model_name," is completed")
  #out = out_dir + "/" + model_name + "/high_then_low"
  #run_trainer(model_name=model_name,out_dir= out,epoch=50,df_train = df_train_low,df_valid=df_valid)

# %%
#run_both_training("Tomas23/twitter-roberta-base-mar2022-finetuned-sentiment")



#run_both_training("cardiffnlp/bertweet-base-sentiment")
run_both_training("svalabs/twitter-xlm-roberta-bitcoin-sentiment")

#run_both_training("cardiffnlp/twitter-xlm-roberta-base-sentiment")
#run_both_training("amansolanki/autonlp-Tweet-Sentiment-Extraction-20114061")

run_both_training("finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# starting  svalabs/twitter-xlm-roberta-bitcoin-sentiment
# Downloading tokenizer_config.json:   0%|          | 0.00/590 [00:00<?, ?B/s]
# Downloading sentencepiece.bpe.model:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
# Dataset({
#     features: ['label', 'text', 'input_ids', 'attention_mask'],
#     num_rows: 539
# })
# Dataset({
#     features: ['label', 'text', 'input_ids', 'attention_mask'],
#     num_rows: 1195
# })
# Downloading builder script:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/961 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.04G [00:00<?, ?B/s]
# The following columns in the training set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 539
#   Num Epochs = 40
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 1360
#     <div>
#
#       <progress value='1021' max='1360' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1021/1360 33:54 < 11:16, 0.50 it/s, Epoch 30/40]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Matthews Correlation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.952300</td>
#       <td>1.039319</td>
#       <td>0.252398</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.779500</td>
#       <td>0.960521</td>
#       <td>0.271879</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.686200</td>
#       <td>0.986685</td>
#       <td>0.291113</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.603500</td>
#       <td>1.009317</td>
#       <td>0.248316</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.561500</td>
#       <td>1.079756</td>
#       <td>0.252717</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.541500</td>
#       <td>1.093142</td>
#       <td>0.246025</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.495900</td>
#       <td>1.113782</td>
#       <td>0.222801</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.476700</td>
#       <td>1.212385</td>
#       <td>0.240143</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.424700</td>
#       <td>1.237429</td>
#       <td>0.245923</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.387000</td>
#       <td>1.261821</td>
#       <td>0.251641</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.362400</td>
#       <td>1.339871</td>
#       <td>0.239774</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.341600</td>
#       <td>1.350886</td>
#       <td>0.255740</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.319200</td>
#       <td>1.397990</td>
#       <td>0.242226</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.300800</td>
#       <td>1.450098</td>
#       <td>0.257915</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.283800</td>
#       <td>1.477688</td>
#       <td>0.241677</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.268100</td>
#       <td>1.498801</td>
#       <td>0.245213</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.242000</td>
#       <td>1.550010</td>
#       <td>0.239107</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.240100</td>
#       <td>1.542725</td>
#       <td>0.240550</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.222400</td>
#       <td>1.536015</td>
#       <td>0.246836</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.197100</td>
#       <td>1.593440</td>
#       <td>0.245649</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.182000</td>
#       <td>1.587024</td>
#       <td>0.249775</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.194800</td>
#       <td>1.622916</td>
#       <td>0.255497</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.157700</td>
#       <td>1.721751</td>
#       <td>0.247675</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.164200</td>
#       <td>1.757032</td>
#       <td>0.252370</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.160100</td>
#       <td>1.767030</td>
#       <td>0.252729</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.145800</td>
#       <td>1.825366</td>
#       <td>0.248574</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.162200</td>
#       <td>1.856410</td>
#       <td>0.247786</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.130300</td>
#       <td>1.875732</td>
#       <td>0.253491</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.142200</td>
#       <td>1.892661</td>
#       <td>0.247852</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.139500</td>
#       <td>1.909267</td>
#       <td>0.248225</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-34
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-34/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-34/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-34/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-34/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-68
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-68/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-68/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-68/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-68/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-102
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-102/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-102/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-102/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-102/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-34] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-136
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-136/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-136/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-136/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-136/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-68] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-170
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-170/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-170/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-170/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-170/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-136] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-204
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-204/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-204/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-204/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-204/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-170] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-238
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-238/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-238/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-238/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-238/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-204] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-272
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-272/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-272/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-272/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-272/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-238] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-306
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-306/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-306/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-306/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-306/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-272] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-340
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-340/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-340/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-340/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-340/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-306] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-374
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-374/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-374/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-374/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-374/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-340] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-408
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-408/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-408/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-408/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-408/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-374] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-442
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-442/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-442/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-442/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-442/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-408] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-476
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-476/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-476/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-476/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-476/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-442] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-510
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-510/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-510/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-510/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-510/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-476] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-544
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-544/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-544/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-544/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-544/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-510] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-578
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-578/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-578/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-578/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-578/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-544] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-612
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-612/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-612/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-612/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-612/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-578] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-646
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-646/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-646/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-646/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-646/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-612] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-680
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-680/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-680/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-680/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-680/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-646] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-714
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-714/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-714/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-714/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-714/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-680] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-748
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-748/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-748/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-748/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-748/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-714] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-782
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-782/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-782/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-782/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-782/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-748] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-816
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-816/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-816/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-816/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-816/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-782] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-850
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-850/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-850/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-850/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-850/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-816] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-884
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-884/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-884/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-884/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-884/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-850] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-918
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-918/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-918/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-918/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-918/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-884] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-952
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-952/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-952/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-952/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-952/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-918] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-986
# Configuration saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-986/config.json
# Model weights saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-986/pytorch_model.bin
# tokenizer config file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-986/tokenizer_config.json
# Special tokens file saved in /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-986/special_tokens_map.json
# Deleting older checkpoint [/content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-952] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `XLMRobertaForSequenceClassification.forward` and have been ignored: text. If text are not expected by `XLMRobertaForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1195
#   Batch size = 16
# Saving model checkpoint to /content/drive/MyDrive/fyp/fyp2/final models and datasets/final models/svalabs/twitter-xlm-roberta-bitcoin-sentiment/high/checkpoint-1020

# %%
# !nvidia-smi

# %%
# !kill -9 -1
