# %%
import pandas as pd

df = pd.read_csv("/content/test_evals.csv")
df = df.set_index("Unnamed: 0")
display(df)
# Out:
#                                                     MATTHEW'S CORRELATION COEFFICIENT (MCC)
# Unnamed: 0
# amansolanki/autonlp-Tweet-Sentiment-Extraction-...                                 0.188102
# svalabs/twitter-xlm-roberta-bitcoin-sentiment_V...                                 0.219705
# elozano/tweet_sentiment_eval_V2/high/checkpoint...                                 0.229557
# finiteautomata/bertweet-base-sentiment-analysis...                                 0.233378
# amansolanki/autonlp-Tweet-Sentiment-Extraction-...                                 0.239312
# svalabs/twitter-xlm-roberta-bitcoin-sentiment_V...                                 0.269738
# cardiffnlp/bertweet-base-sentiment_V2/high/chec...                                 0.270206
# Tomas23/twitter-roberta-base-mar2022-finetuned-...                                 0.270408
# finiteautomata/bertweet-base-sentiment-analysis...                                 0.412490
# ...
